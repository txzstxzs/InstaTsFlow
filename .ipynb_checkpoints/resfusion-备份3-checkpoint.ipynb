# %%
import os
import argparse
import json
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
plt.rc('font',family='Times New Roman') # 设置全局字体

import umap                         # 注意版本对应 numba0.56.4到0.58.1 对应 numpy1.23.4
import seaborn as sns 

from utils.util import find_max_epoch, print_size, training_loss, calc_diffusion_hyperparams
from utils.util import get_mask_mnr, get_mask_bm, get_mask_rm, get_mask_mcar

from imputers.DiffWaveImputer import DiffWaveImputer
from imputers.SSSDSAImputer import SSSDSAImputer
from imputers.SSSDS4Imputer import SSSDS4Imputer
# from imputers.CSDI import CSDIImputer  # csdi在当前方法里因为参数不一致不好用

import time
import gc
from tqdm import tqdm

# %%
parser = argparse.ArgumentParser()
parser.add_argument('-c', '--config', type=str, default='./config/config_SSSDS4-sp500.json')  # 用sp500数据集
                                                                                                                      
args = parser.parse_args(args=[])
print(args)

with open(args.config) as f:
    data = f.read()

config = json.loads(data)
print(config)
# Out:
# Namespace(config='./config/config_SSSDS4-sp500.json')
# {'diffusion_config': {'T': 200, 'beta_0': 0.0001, 'beta_T': 0.02}, 'wavenet_config': {'in_channels': 6, 'out_channels': 6, 'num_res_layers': 36, 'res_channels': 128, 'skip_channels': 128, 'diffusion_step_embed_dim_in': 128, 'diffusion_step_embed_dim_mid': 512, 'diffusion_step_embed_dim_out': 512, 's4_lmax': 100, 's4_d_state': 64, 's4_dropout': 0.0, 's4_bidirectional': 1, 's4_layernorm': 1}, 'train_config': {'output_directory': './results/sp500/90', 'ckpt_iter': 'max', 'iters_per_ckpt': 500, 'iters_per_logging': 500, 'n_iters': 1000, 'learning_rate': 0.0002, 'only_generate_missing': 1, 'use_model': 2, 'masking': 'rm', 'missing_k': 20}, 'trainset_config': {'train_data_path': './datasets/sp500.npy', 'test_data_path': './datasets/sp500.npy', 'segment_length': 100, 'sampling_rate': 100}, 'gen_config': {'output_directory': './results/sp500/90', 'ckpt_path': './results/sp500/90/'}}

# %%
train_config = config["train_config"]  # training parameters

global trainset_config
trainset_config = config["trainset_config"]  # to load trainset

global diffusion_config
diffusion_config = config["diffusion_config"]  # basic hyperparameters

global diffusion_hyperparams
diffusion_hyperparams = calc_diffusion_hyperparams(
                      **diffusion_config)  # 具体的beta alpha值   dictionary of all diffusion hyperparameters

global model_config

'选择数据集 会影响后面一些列参数'
data_name = 'sp500'
# data_name = 'ETTh1'
# data_name = 'energy'
# data_name = 'mujoco'

if data_name == 'sp500':
    trainset_config['train_data_path'] = "./datasets/sp500.npy"
    
if data_name == 'energy':
    trainset_config['train_data_path'] = "./datasets/energy.npy"
    
if data_name == 'ETTh1':
    trainset_config['train_data_path'] = "./datasets/ETTh1.npy"
    
if data_name == 'mujoco':
    trainset_config['train_data_path'] = "./datasets/MuJoCo.npy"

print(trainset_config)


# model_config = config['sashimi_config']
model_config = config['wavenet_config']
    
    
# print(diffusion_hyperparams)
print(train_config)
print(model_config)

'修改配置 可以在配置文件里修改 也可以直接修改'



if data_name == 'sp500':
    model_config['in_channels'] =  6   
    model_config['out_channels'] = 6   
    
if data_name == 'energy':
    model_config['in_channels'] =  26   
    model_config['out_channels'] = 26  
    
if data_name == 'ETTh1':
    model_config['in_channels'] =  7   
    model_config['out_channels'] = 7  
    
if data_name == 'mujoco':
    model_config['in_channels'] =  14   
    model_config['out_channels'] = 14  



model_config['num_res_layers'] = 18            # 对于sp500 残差层的数量会和损失下降的平滑度有关 36比18平滑 但是也不一定 可能看随机性

'对于energy数据集 属性较多 以下参数要翻倍'

if data_name == 'energy':
    model_config['res_channels'] = 256             # 中间维度从128变为256后 收敛速度好像快了一些  但最终的损失值还是差不多
    model_config['skip_channels'] =256 
else:
    model_config['res_channels'] = 128           
    model_config['skip_channels'] = 128
    

print(model_config)
# Out:
# {'train_data_path': './datasets/sp500.npy', 'test_data_path': './datasets/sp500.npy', 'segment_length': 100, 'sampling_rate': 100}
# {'output_directory': './results/sp500/90', 'ckpt_iter': 'max', 'iters_per_ckpt': 500, 'iters_per_logging': 500, 'n_iters': 1000, 'learning_rate': 0.0002, 'only_generate_missing': 1, 'use_model': 2, 'masking': 'rm', 'missing_k': 20}
# {'in_channels': 6, 'out_channels': 6, 'num_res_layers': 36, 'res_channels': 128, 'skip_channels': 128, 'diffusion_step_embed_dim_in': 128, 'diffusion_step_embed_dim_mid': 512, 'diffusion_step_embed_dim_out': 512, 's4_lmax': 100, 's4_d_state': 64, 's4_dropout': 0.0, 's4_bidirectional': 1, 's4_layernorm': 1}
# {'in_channels': 6, 'out_channels': 6, 'num_res_layers': 18, 'res_channels': 128, 'skip_channels': 128, 'diffusion_step_embed_dim_in': 128, 'diffusion_step_embed_dim_mid': 512, 'diffusion_step_embed_dim_out': 512, 's4_lmax': 100, 's4_d_state': 64, 's4_dropout': 0.0, 's4_bidirectional': 1, 's4_layernorm': 1}

# %%
# map diffusion hyperparameters to gpu
for key in diffusion_hyperparams:
    if key != "T":
        diffusion_hyperparams[key] = diffusion_hyperparams[key].cuda()

        
dh = diffusion_hyperparams
T, Alpha, Alpha_bar, Sigma = dh["T"], dh["Alpha"], dh["Alpha_bar"], dh["Sigma"]
Beta = 1 - Alpha

print(T)
print(Alpha)      # 1 - 0.98
print(Alpha_bar)  # 1 - 0.13
print(Beta)       # 0 - 0.02

def get_acc_point(alphas_hat):
        """
            Calculate Acceleration Point, according to formula 27
        """
        abs_dist = torch.abs(torch.sqrt(alphas_hat) - 0.5)
        return abs_dist.argmin() + 1
    
T_acc = get_acc_point(Alpha_bar).item()
print( T_acc )

abs_dist = torch.abs(torch.sqrt(Alpha_bar[165]) - 0.5)
print( abs_dist )
# Out:
# 200
# tensor([0.9999, 0.9998, 0.9997, 0.9996, 0.9995, 0.9994, 0.9993, 0.9992, 0.9991,
#         0.9990, 0.9989, 0.9988, 0.9987, 0.9986, 0.9985, 0.9984, 0.9983, 0.9982,
#         0.9981, 0.9980, 0.9979, 0.9978, 0.9977, 0.9976, 0.9975, 0.9974, 0.9973,
#         0.9972, 0.9971, 0.9970, 0.9969, 0.9968, 0.9967, 0.9966, 0.9965, 0.9964,
#         0.9963, 0.9962, 0.9961, 0.9960, 0.9959, 0.9958, 0.9957, 0.9956, 0.9955,
#         0.9954, 0.9953, 0.9952, 0.9951, 0.9950, 0.9949, 0.9948, 0.9947, 0.9946,
#         0.9945, 0.9944, 0.9943, 0.9942, 0.9941, 0.9940, 0.9939, 0.9938, 0.9937,
#         0.9936, 0.9935, 0.9934, 0.9933, 0.9932, 0.9931, 0.9930, 0.9929, 0.9928,
#         0.9927, 0.9926, 0.9925, 0.9924, 0.9923, 0.9922, 0.9921, 0.9920, 0.9919,
#         0.9918, 0.9917, 0.9916, 0.9915, 0.9914, 0.9913, 0.9912, 0.9911, 0.9910,
#         0.9909, 0.9908, 0.9907, 0.9906, 0.9905, 0.9904, 0.9903, 0.9902, 0.9901,
#         0.9900, 0.9899, 0.9898, 0.9897, 0.9896, 0.9895, 0.9894, 0.9893, 0.9892,
#         0.9891, 0.9890, 0.9889, 0.9888, 0.9887, 0.9886, 0.9885, 0.9884, 0.9883,
#         0.9882, 0.9881, 0.9880, 0.9879, 0.9878, 0.9877, 0.9876, 0.9875, 0.9874,
#         0.9873, 0.9872, 0.9871, 0.9870, 0.9869, 0.9868, 0.9867, 0.9866, 0.9865,
#         0.9864, 0.9863, 0.9862, 0.9861, 0.9860, 0.9859, 0.9858, 0.9857, 0.9856,
#         0.9855, 0.9854, 0.9853, 0.9852, 0.9851, 0.9850, 0.9849, 0.9848, 0.9847,
#         0.9846, 0.9845, 0.9844, 0.9843, 0.9842, 0.9841, 0.9840, 0.9839, 0.9838,
#         0.9837, 0.9836, 0.9835, 0.9834, 0.9833, 0.9832, 0.9831, 0.9830, 0.9829,
#         0.9828, 0.9827, 0.9826, 0.9825, 0.9824, 0.9823, 0.9822, 0.9821, 0.9820,
#         0.9819, 0.9818, 0.9817, 0.9816, 0.9815, 0.9814, 0.9813, 0.9812, 0.9811,
#         0.9810, 0.9809, 0.9808, 0.9807, 0.9806, 0.9805, 0.9804, 0.9803, 0.9802,
#         0.9801, 0.9800], device='cuda:0')
# tensor([0.9999, 0.9997, 0.9994, 0.9990, 0.9985, 0.9979, 0.9972, 0.9964, 0.9955,
#         0.9945, 0.9934, 0.9922, 0.9909, 0.9895, 0.9881, 0.9865, 0.9848, 0.9830,
#         0.9812, 0.9792, 0.9771, 0.9750, 0.9728, 0.9704, 0.9680, 0.9655, 0.9629,
#         0.9602, 0.9574, 0.9545, 0.9516, 0.9485, 0.9454, 0.9422, 0.9389, 0.9355,
#         0.9320, 0.9285, 0.9249, 0.9212, 0.9174, 0.9135, 0.9096, 0.9056, 0.9015,
#         0.8974, 0.8932, 0.8889, 0.8845, 0.8801, 0.8756, 0.8711, 0.8664, 0.8618,
#         0.8570, 0.8522, 0.8474, 0.8425, 0.8375, 0.8325, 0.8274, 0.8223, 0.8171,
#         0.8118, 0.8066, 0.8012, 0.7959, 0.7905, 0.7850, 0.7795, 0.7740, 0.7684,
#         0.7628, 0.7572, 0.7515, 0.7458, 0.7400, 0.7342, 0.7284, 0.7226, 0.7168,
#         0.7109, 0.7050, 0.6991, 0.6931, 0.6872, 0.6812, 0.6752, 0.6692, 0.6632,
#         0.6571, 0.6511, 0.6450, 0.6390, 0.6329, 0.6268, 0.6207, 0.6147, 0.6086,
#         0.6025, 0.5964, 0.5903, 0.5842, 0.5782, 0.5721, 0.5660, 0.5600, 0.5539,
#         0.5479, 0.5419, 0.5358, 0.5298, 0.5238, 0.5179, 0.5119, 0.5060, 0.5001,
#         0.4942, 0.4883, 0.4824, 0.4766, 0.4708, 0.4650, 0.4592, 0.4535, 0.4478,
#         0.4421, 0.4364, 0.4308, 0.4252, 0.4196, 0.4141, 0.4086, 0.4031, 0.3977,
#         0.3922, 0.3869, 0.3815, 0.3762, 0.3710, 0.3657, 0.3605, 0.3554, 0.3503,
#         0.3452, 0.3401, 0.3351, 0.3302, 0.3253, 0.3204, 0.3155, 0.3108, 0.3060,
#         0.3013, 0.2966, 0.2920, 0.2874, 0.2829, 0.2784, 0.2739, 0.2695, 0.2651,
#         0.2608, 0.2565, 0.2523, 0.2481, 0.2440, 0.2399, 0.2358, 0.2318, 0.2278,
#         0.2239, 0.2201, 0.2162, 0.2124, 0.2087, 0.2050, 0.2014, 0.1978, 0.1942,
#         0.1907, 0.1872, 0.1838, 0.1804, 0.1771, 0.1738, 0.1705, 0.1673, 0.1642,
#         0.1610, 0.1580, 0.1549, 0.1519, 0.1490, 0.1461, 0.1432, 0.1404, 0.1376,
#         0.1349, 0.1322], device='cuda:0')
# tensor([0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009,
#         0.0010, 0.0011, 0.0012, 0.0013, 0.0014, 0.0015, 0.0016, 0.0017, 0.0018,
#         0.0019, 0.0020, 0.0021, 0.0022, 0.0023, 0.0024, 0.0025, 0.0026, 0.0027,
#         0.0028, 0.0029, 0.0030, 0.0031, 0.0032, 0.0033, 0.0034, 0.0035, 0.0036,
#         0.0037, 0.0038, 0.0039, 0.0040, 0.0041, 0.0042, 0.0043, 0.0044, 0.0045,
#         0.0046, 0.0047, 0.0048, 0.0049, 0.0050, 0.0051, 0.0052, 0.0053, 0.0054,
#         0.0055, 0.0056, 0.0057, 0.0058, 0.0059, 0.0060, 0.0061, 0.0062, 0.0063,
#         0.0064, 0.0065, 0.0066, 0.0067, 0.0068, 0.0069, 0.0070, 0.0071, 0.0072,
#         0.0073, 0.0074, 0.0075, 0.0076, 0.0077, 0.0078, 0.0079, 0.0080, 0.0081,
#         0.0082, 0.0083, 0.0084, 0.0085, 0.0086, 0.0087, 0.0088, 0.0089, 0.0090,
#         0.0091, 0.0092, 0.0093, 0.0094, 0.0095, 0.0096, 0.0097, 0.0098, 0.0099,
#         0.0100, 0.0101, 0.0102, 0.0103, 0.0104, 0.0105, 0.0106, 0.0107, 0.0108,
#         0.0109, 0.0110, 0.0111, 0.0112, 0.0113, 0.0114, 0.0115, 0.0116, 0.0117,
#         0.0118, 0.0119, 0.0120, 0.0121, 0.0122, 0.0123, 0.0124, 0.0125, 0.0126,
#         0.0127, 0.0128, 0.0129, 0.0130, 0.0131, 0.0132, 0.0133, 0.0134, 0.0135,
#         0.0136, 0.0137, 0.0138, 0.0139, 0.0140, 0.0141, 0.0142, 0.0143, 0.0144,
#         0.0145, 0.0146, 0.0147, 0.0148, 0.0149, 0.0150, 0.0151, 0.0152, 0.0153,
#         0.0154, 0.0155, 0.0156, 0.0157, 0.0158, 0.0159, 0.0160, 0.0161, 0.0162,
#         0.0163, 0.0164, 0.0165, 0.0166, 0.0167, 0.0168, 0.0169, 0.0170, 0.0171,
#         0.0172, 0.0173, 0.0174, 0.0175, 0.0176, 0.0177, 0.0178, 0.0179, 0.0180,
#         0.0181, 0.0182, 0.0183, 0.0184, 0.0185, 0.0186, 0.0187, 0.0188, 0.0189,
#         0.0190, 0.0191, 0.0192, 0.0193, 0.0194, 0.0195, 0.0196, 0.0197, 0.0198,
#         0.0199, 0.0200], device='cuda:0')
# 166
# tensor(0.0019, device='cuda:0')

# %%
# output_directory = './results/mujoco/90'
# ckpt_iter = 'max'

# n_iters = 10000
# iters_per_ckpt = 100
# iters_per_logging = 100
# batch_size_per_gpu         # SA模型需要 S4和DiffWave不需要        
learning_rate = 0.0002

use_model = 2

only_generate_missing = 1       # 加噪方式 全局还是局部加噪
masking = 'rm'               # 缺失值产生方式
missing_k = 20

# %%
net = SSSDS4Imputer(**model_config).cuda()    # 使用这个模型
# net = DiffWaveImputer(**model_config).cuda()
# net = SSSDSAImputer(**model_config).cuda()

print_size(net)

# optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)
# Out:
# SSSDS4Imputer Parameters: 7.547142M

# %%
'数据读取与分割 制作dataloader 注意读取的时npy还是csv'
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader


training_data = np.load(trainset_config['train_data_path'])
np.random.shuffle(training_data)
print(training_data.shape)


Number = training_data.shape[0]
Length = training_data.shape[1]
Attribute = training_data.shape[2]
print(Number, Length, Attribute)


training_data = torch.split( torch.tensor(training_data),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
print(len(training_data), training_data[3].shape, training_data[-1].shape)           # 最后一个batch样本数可能会少一些
print(training_data[0][0][0:2])
# Out:
# (5775, 30, 6)
# 5775 30 6
# 46 torch.Size([128, 30, 6]) torch.Size([15, 30, 6])
# tensor([[0.3644, 0.3633, 0.0462, 0.3636, 0.3626, 0.3604],
#         [0.3659, 0.3651, 0.0355, 0.3648, 0.3605, 0.3584]], dtype=torch.float64)

# %%
def resfusion_x0_to_xt(x_0: torch.Tensor, alpha_hat_t: torch.Tensor, residual_term: torch.Tensor, noise: torch.Tensor) \
        -> torch.Tensor:
    """
    Compute x_t from x_0 with formula 20 from Resfusion
    :param x_0: the image without noise
    :param alpha_hat_t: the cumulated variance schedule at time t
    :param residual_term: the residual term
    :param noise: pure noise from N(0, 1)
    :return: the noised image x_t at step t
    """
    return (torch.sqrt(alpha_hat_t) * x_0 + (1 - torch.sqrt(alpha_hat_t)) * residual_term
            + torch.sqrt(1 - alpha_hat_t) * noise)


def ddpm_x0_to_xt(x_0: torch.Tensor, alpha_hat_t: torch.Tensor, noise: torch.Tensor) -> torch.Tensor:
    """
    Compute x_t from x_0 using a closed form using theorem from original DDPM paper (Ho et al.)
    :param x_0: the image without noise
    :param alpha_hat_t: the cumulated variance schedule at time t
    :param noise: pure noise from N(0, 1)
    :return: the noised image x_t at step t
    """
    return torch.sqrt(alpha_hat_t) * x_0 + torch.sqrt(1 - alpha_hat_t) * noise

# %%
epoch = 20
n_iters = epoch * ( len(training_data) )

iters = 0
mr = 0.3

loss_list=[]
net = SSSDS4Imputer(**model_config).cuda()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
'掩码产生过程和训练'
'-----这里每个batch里 每个数据的掩码都一样 不同batch里数据的掩码不一样-----'
'不同的缺失率要另外训练'
'无监督任务的话缺失掩码应该没有用'

'这里训练时选择的是全局加噪 可以考虑只在缺失处加噪 参考sssd 这样的话在训练和采样时 要保证观测处不变 只在缺失处加减噪 同时只计算缺失处的损失'
while iters < n_iters + 1:         
    for batch in training_data:           # [128, 30, 6]
        
        X_0 = batch.float().cuda()  
        B = X_0.shape[0]
        L = X_0.shape[1]
        D = X_0.shape[2]
        
        '退化数据的几种选择 全0 噪声 缺失数据'
        '如果用缺失数作为退化数据 缺失部分可以看成0 那么计算resnoise损失是就不用加掩码'
        '也可以计算resnoise损失时加上掩码 只计算观测部分的损失'
#         X_0_hat = torch.zeros_like(X_0)   #  全0 [128, 3, 32, 32]  可以选择全0或噪声
#         X_0_hat = torch.randn_like(X_0)   #  全1

        '4种缺失场景'
        missing_length = int( mr * L )
#         mask = get_mask_rm( X_0[0], missing_length)      # 原数据乘以缺失掩码
#         mask = get_mask_mnr( X_0[0], missing_length) 
#         mask = get_mask_bm( X_0[0], missing_length) 
        mask = get_mask_mcar( X_0[0], mr)  # mcar缺失法的输入参数和另外单个不一样 直接输入缺失率
    
        mask = mask.repeat(X_0.size()[0], 1, 1).float().cuda()
        X_0_hat = X_0*mask

        residual_term = X_0_hat - X_0 
        
        t: torch.Tensor = torch.randint(0, T_acc, (X_0.shape[0],) ).cuda()     #  
        alpha_hat = Alpha_bar[t].reshape(-1, 1, 1).cuda()                      # 
        noise = torch.randn_like(X_0)
        
        x_t = resfusion_x0_to_xt(X_0, alpha_hat, residual_term, noise) 
        
        alpha = Alpha[t].reshape(-1, 1, 1).cuda() 
        beta = Beta[t].reshape(-1, 1, 1).cuda() 
        
        resnoise = noise + (1 - torch.sqrt(alpha)) * torch.sqrt(1 - alpha_hat) / beta * residual_term
        
    
        '两种训练模式 有条件和无条件 有条件是融入观测值和掩码 二者会拼接'
        '第二个参数是完整数据 输入模型后会和掩码写成 变成观测值 是用观测值作为条件 而不是完整数据作为条件 这种写法有些迷惑性 直接写成X_0*mask更更好'
        '这里和sssd里的全局加噪方式一致 可以考虑只对缺失位置加噪'
        pred_resnoise = net( (x_t.permute(0, 2, 1), X_0.permute(0, 2, 1), mask.permute(0, 2, 1), t.view(B, 1),) )  #  [B, 6, 30]
#         pred_resnoise = net( (x_t.permute(0, 2, 1), None, None, t.view(B, 1),) ) 
        pred_resnoise = pred_resnoise.permute(0, 2, 1)
        
        optimizer.zero_grad()
        
        '训练时用mse作为损失好像性能好一些'
        '考虑只计算缺失处的损失'

        loss = F.mse_loss(input=pred_resnoise, target=resnoise )  
#         loss = F.mse_loss(input=pred_resnoise*(1-mask), target=resnoise*(1-mask) )  
#         loss = torch.sqrt( F.mse_loss(input=pred_resnoise, target=resnoise) )  # 损失可以除以batchsize
#         loss = F.smooth_l1_loss(input=pred_resnoise, target=resnoise)
    
        loss.backward()
        optimizer.step()
        loss_list.append(loss.item())
        iters += 1

# %%
print(len(loss_list))
rmse = list( map(lambda x: x ** (1/2), loss_list) )

print( loss_list[-20 : ] )
print( rmse[-20 : ] )

plt.figure()
plt.plot(loss_list)
plt.plot(rmse)
# Out:
# 966
# [0.017335664480924606, 0.013932249508798122, 0.00938406027853489, 0.013858480378985405, 0.011672082357108593, 0.011674007400870323, 0.016825363039970398, 0.01354712713509798, 0.012824691832065582, 0.015396916307508945, 0.0186399444937706, 0.013196578249335289, 0.012323271483182907, 0.0170733779668808, 0.011985156685113907, 0.013499760068953037, 0.013714761473238468, 0.013296661898493767, 0.013294914737343788, 0.006149520631879568]
# [0.13166497059174323, 0.11803495036978717, 0.09687135943370924, 0.11772204712366076, 0.10803741184010561, 0.10804632062624957, 0.12971261711942442, 0.11639212660269585, 0.11324615592621934, 0.12408431128675754, 0.13652818204960687, 0.11487636070721986, 0.11101023143468762, 0.13066513676907393, 0.10947674038403732, 0.11618846788280254, 0.11711004001894317, 0.11531115253302157, 0.11530357642911077, 0.07841887930772518]

# %%
'保存和导入模型参数'
# torch.save( net.state_dict(),"./results/sp500_resfusion_mcar0.3.pth" )
# torch.save( net.state_dict(),"./results/sp500_resfusion_mcar0.6.pth" )
# torch.save( net.state_dict(),"./results/sp500_resfusion_mnr0.3.pth" )
# torch.save( net.state_dict(),"./results/sp500_resfusion_mnr0.6.pth" )


# torch.save( net.state_dict(),"./results/ETTh1_resfusion_mcar0.3.pth" )
# torch.save( net.state_dict(),"./results/ETTh1_resfusion_mcar0.6.pth" )
# torch.save( net.state_dict(),"./results/ETTh1_resfusion_mnr0.3.pth" )
# torch.save( net.state_dict(),"./results/ETTh1_resfusion_mnr0.6.pth" )


# torch.save( net.state_dict(),"./results/energy_resfusion_mcar0.3.pth" )
# torch.save( net.state_dict(),"./results/energy_resfusion_mcar0.6.pth" )
# torch.save( net.state_dict(),"./results/energy_resfusion_mnr0.3.pth" )
# torch.save( net.state_dict(),"./results/energy_resfusion_mnr0.6.pth" )


torch.save( net.state_dict(),"./results/mujoco_resfusion_mcar0.3.pth" )
# torch.save( net.state_dict(),"./results/mujoco_resfusion_mcar0.6.pth" )
# torch.save( net.state_dict(),"./results/mujoco_resfusion_mnr0.3.pth" )
# torch.save( net.state_dict(),"./results/mujoco_resfusion_mnr0.6.pth" )


net = SSSDS4Imputer(**model_config).cuda()
# net.load_state_dict(torch.load( "./results/sp500_resfusion_mcar0.3.pth" ))
# net.load_state_dict(torch.load( "./results/sp500_resfusion_mcar0.6.pth" ))
# net.load_state_dict(torch.load( "./results/sp500_resfusion_mnr0.3.pth" ))
# net.load_state_dict(torch.load( "./results/sp500_resfusion_mnr0.6.pth" ))


# net.load_state_dict(torch.load( "./results/ETTh1_resfusion_mcar0.3.pth" ))
# net.load_state_dict(torch.load( "./results/ETTh1_resfusion_mcar0.6.pth" ))
# net.load_state_dict(torch.load( "./results/ETTh1_resfusion_mnr0.3.pth" ))
# net.load_state_dict(torch.load( "./results/ETTh1_resfusion_mnr0.6.pth" ))


# net.load_state_dict(torch.load( "./results/energy_resfusion_mcar0.3.pth" ))
# net.load_state_dict(torch.load( "./results/energy_resfusion_mcar0.6.pth" ))
# net.load_state_dict(torch.load( "./results/energy_resfusion_mnr0.3.pth" ))
# net.load_state_dict(torch.load( "./results/energy_resfusion_mnr0.6.pth" ))


net.load_state_dict(torch.load( "./results/mujoco_resfusion_mcar0.3.pth" ))
# net.load_state_dict(torch.load( "./results/mujoco_resfusion_mcar0.6.pth" ))
# net.load_state_dict(torch.load( "./results/mujoco_resfusion_mnr0.3.pth" ))
# net.load_state_dict(torch.load( "./results/mujoco_resfusion_mnr0.6.pth" ))

net.eval()
# Out:
# SSSDS4Imputer(
#   (init_conv): Sequential(
#     (0): Conv(
#       (conv): Conv1d(14, 128, kernel_size=(1,), stride=(1,))
#     )
#     (1): ReLU()
#   )
#   (residual_layer): Residual_group(
#     (fc_t1): Linear(in_features=128, out_features=512, bias=True)
#     (fc_t2): Linear(in_features=512, out_features=512, bias=True)
#     (residual_blocks): ModuleList(
#       (0): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (1): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (2): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (3): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (4): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (5): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (6): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (7): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (8): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (9): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (10): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (11): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (12): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (13): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (14): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (15): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (16): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (17): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(28, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
#   (final_conv): Sequential(
#     (0): Conv(
#       (conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#     )
#     (1): ReLU()
#     (2): ZeroConv1d(
#       (conv): Conv1d(128, 14, kernel_size=(1,), stride=(1,))
#     )
#   )
# )

# %%
def std_normal(size):
    """
    Generate the standard Gaussian variable of a certain size
    """
    return torch.normal(0, 1, size=size).cuda()

size = (Number, Attribute, Length )
noise = std_normal(size)

'根据训练时退化图像X_0_hat是全0还是噪声 选择对应的采样时的起点'
# X_0_hat = torch.zeros_like(noise)  
X_0_hat = torch.randn_like(noise)


alpha_hat = Alpha_bar[T_acc - 1].reshape(-1, 1, 1).cuda() 
x = ddpm_x0_to_xt(X_0_hat, alpha_hat, noise)     # 采样起点
print(x.shape)

print(Sigma.shape)
# Out:
# torch.Size([8000, 14, 100])
# torch.Size([200])

# %%
'这里选择缺失数据的加噪值作为采样起点'
training_data = np.load(trainset_config['train_data_path'])
np.random.shuffle(training_data)
print(training_data.shape)

training_data = torch.from_numpy(training_data).float().cuda()


# size=(5775,30,6)
size = (Number, Length, Attribute )
noise = std_normal(size)


# Mask = get_mask_rm( noise[0], missing_length)      # 原数据乘以缺失掩码
# Mask = get_mask_mnr( X_0[0], missing_length) 
# Mask = get_mask_bm( X_0[0], missing_length) 
Mask = get_mask_mcar( noise[0], mr)

print( torch.sum(Mask.eq(1)) )
Mask = Mask.repeat(noise.size()[0], 1, 1).float().cuda()
print(Mask.shape)

# X_0_hat = training_data.reshape(-1, 30, 6) * Mask   # 观测值
X_0_hat = training_data.reshape(-1, Length, Attribute) * Mask   # 观测值
# print(X_0_hat.shape)
# print(X_0_hat[0])
# print(Mask[0])
# print(Mask[10])

alpha_hat = Alpha_bar[T_acc - 1].reshape(-1, 1, 1).cuda() 
X_T = ddpm_x0_to_xt(X_0_hat, alpha_hat, noise)     # 观测值加噪 作为采样起点
print(X_T.shape)
# Out:
# (8000, 100, 14)
# tensor(980)
# torch.Size([8000, 100, 14])
# torch.Size([8000, 100, 14])

# %%
X = X_T.permute(0, 2, 1)

'如果只计算100个样本的时间 加上[0:100] 模型里的几个输入也这样加上 ddpm的话最后的噪声也要加'
'ddpm时间8.9左右 ddim8.2左右 完整样本时间150左右'
'扩散步设为200的即sssd话 ddpm为10.5左右 ddim为 9.5  完整样本时间178左右'
# X = X_T.permute(0, 2, 1)[0:100]

print(X.shape)

'ddpm减噪'
start_time = time.time()
with torch.no_grad():      
        for t in tqdm( range( T_acc - 1, -1, -1) ):   
#         for t in range(T_acc - 1, 0, -1):   
#         for t in range(T_acc , 0, -1):   
                
            diffusion_steps = (t * torch.ones((size[0], 1))).cuda()    
        
            '两种形式的模型输入条件 第一个是不用条件 第二个是用观测值和掩码'
#             epsilon_theta = net((x, None, None, diffusion_steps,))            
            epsilon_theta = net((X, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), diffusion_steps,)) 
            
            
            alpha = Alpha[t].reshape(-1, 1, 1).cuda() 
            beta = Beta[t].reshape(-1, 1, 1).cuda() 
            alpha_hat = Alpha_bar[t].reshape(-1, 1, 1).cuda()      
            sigma = Sigma[t].reshape(-1, 1, 1).cuda()      
            
            X = (X - (1 - alpha) / torch.sqrt(1 - alpha_hat) * epsilon_theta) / torch.sqrt(alpha)
            if t > 0:
#                 X = X + sigma * std_normal( (5775,6,30))    # x0不加标准差  add the variance term to x_{t-1}
                X = X + sigma * std_normal( (Number, Attribute, Length ))


    
'ddim减噪 注意和ddpm不同的时最后的t为1 因为有公式里有t-1'    
'ddim减噪的mse略好于ddpm'
'第三个参数-1可以改成其他负值如-a 实现跨步采样 此时各个系数的关于t的参数也要改'
'而且是此时t可能会在0到|a|之间停下 所以需要多一个判别语句 t到达这个位置后就执行常规的逐步采样到t=1'
# start_time = time.time()
# with torch.no_grad():      
#         for t in range(T_acc - 1 , 0, -1):     
# #         for t in range(T_acc  , 0, -1): 
# #         for t in range(T_acc , -1, -1):    # 下面两个时间步采样结果都不太行
# #         for t in range(T_acc - 1 , -1, -1): 
                
#             diffusion_steps = (t * torch.ones((size[0], 1))).cuda()       
        
        
# #             epsilon_theta = net((x, None, None, diffusion_steps,)) 
#             epsilon_theta = net((X, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), diffusion_steps,)) 
            
            
#             alpha_hat = Alpha_bar[t].reshape(-1, 1, 1).cuda()    
#             alpha_hat_t_minus_1 = Alpha_bar[t-1].reshape(-1, 1, 1).cuda() 

#             X = ( torch.sqrt( alpha_hat_t_minus_1 ) * (X - torch.sqrt(1-alpha_hat) * epsilon_theta) ) / torch.sqrt(alpha_hat) + \
#                                                                                               torch.sqrt(1-alpha_hat_t_minus_1)* epsilon_theta



end_time = time.time()
execution_time = end_time - start_time   # 数据集遍历完一次的时间  sp500差不多9.5s
print(execution_time)
# Out:
# torch.Size([8000, 14, 100])
# 100%|████████████████████████████████████████████████████████████████████████████████| 166/166 [15:00<00:00,  5.43s/it]
# 900.9490242004395

# %%
'-------RMSE-------'
from pypots.utils.metrics import cal_mse,cal_rmse,cal_mae
from pypots.data import load_specific_dataset, mcar, masked_fill


result = X.permute(0, 2, 1)
print(result.shape, Mask.shape)


gt = training_data


'计算rmse或mae'
loss = nn.MSELoss()
# loss = nn.L1Loss()   # mae

output1 = loss(input=result, target=gt)
output2 = loss(input=result*Mask, target=gt*Mask)                 # 观测位置的mse
output3 = loss(input=result*Mask, target=X_0_hat*Mask )             
output4 = loss(input=result*(1-Mask), target=gt*(1-Mask)  )       # 缺失位置的mse  最重要的指标
output5 = loss(input=result[0:1000]*(1-Mask[0:1000]), target=gt[0:1000]*(1-Mask[0:1000])  ) 
output6 = loss(input=result*(1-Mask), target=X_0_hat*(1-Mask) )    

print(output1, torch.sqrt(output1))
print(output2, torch.sqrt(output2))
print(output3, torch.sqrt(output3))
print(output4, torch.sqrt(output4))
print(output5, torch.sqrt(output5))
print(output6, torch.sqrt(output6))

output = loss(input=X_0_hat*Mask, target=gt*Mask )  
print(output, torch.sqrt(output))
# Out:
# torch.Size([8000, 100, 14]) torch.Size([8000, 100, 14])
# tensor(0.0010, device='cuda:0') tensor(0.0317, device='cuda:0')
# tensor(0.0007, device='cuda:0') tensor(0.0261, device='cuda:0')
# tensor(0.0007, device='cuda:0') tensor(0.0261, device='cuda:0')
# tensor(0.0003, device='cuda:0') tensor(0.0181, device='cuda:0')
# tensor(0.0003, device='cuda:0') tensor(0.0181, device='cuda:0')
# tensor(0.0810, device='cuda:0') tensor(0.2846, device='cuda:0')
# tensor(0., device='cuda:0') tensor(0., device='cuda:0')

# %%
mae = cal_mae(result, gt, 1-Mask)  # 只计算缺失位置
mse = cal_mse(result, gt, 1-Mask)
rmse = cal_rmse(result, gt, 1-Mask)
print(mae,mse, rmse)
# Out:
# tensor(0.0252, device='cuda:0') tensor(0.0011, device='cuda:0') tensor(0.0330, device='cuda:0')

# %%
'不用timegan的可视化'
def visualization1(ori, gen):
    
    Number = ori.shape[0]
    
    ori = ori.reshape( Number, -1 )
    gen = gen.reshape( Number, -1 )
    
    pca = PCA(2)     # pca没有用下面的拼接后的数据  效果差不多  但是是否拼接对tsne和umap影响较大
    pca_res1 = pca.fit_transform(ori)
    pca_res2 = pca.fit_transform(gen)

    concat_data = np.concatenate((ori, gen), axis=0)

    tsne = TSNE(n_components=2, verbose=1, perplexity=40,random_state=20,n_iter=500) 
    tsne_res = tsne.fit_transform(concat_data) 

    umap_ = umap.UMAP(random_state=42)
    umap_res = umap_.fit_transform(concat_data)
    
    
    fig = plt.figure(figsize=(12,3))
    plt.subplot(1,4,1)
    
    plt.scatter(pca_res1[:,0],pca_res1[:,1])   
    plt.scatter(pca_res2[:,0],pca_res2[:,1]) 
    
    plt.subplot(1,4,2)
    plt.scatter(tsne_res[:2000,0],tsne_res[:2000,1])
    plt.scatter(tsne_res[Number:Number+2000,0],tsne_res[Number:Number+2000,1])


    plt.subplot(1,4,3)
    plt.scatter(umap_res[:2000, 0], umap_res[:2000, 1],  cmap='Spectral', s=5)
    plt.scatter(umap_res[Number:Number+2000, 0], umap_res[Number:Number+2000, 1],  cmap='Spectral', s=5)

# %%
ori = training_data.cpu()
gen = X.permute(0, 2, 1).cpu().numpy()
visualization1( ori, gen)
# Out:
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 11550 samples in 0.001s...
# [t-SNE] Computed neighbors for 11550 samples in 0.270s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 11550
# [t-SNE] Computed conditional probabilities for sample 2000 / 11550
# [t-SNE] Computed conditional probabilities for sample 3000 / 11550
# [t-SNE] Computed conditional probabilities for sample 4000 / 11550
# [t-SNE] Computed conditional probabilities for sample 5000 / 11550
# [t-SNE] Computed conditional probabilities for sample 6000 / 11550
# [t-SNE] Computed conditional probabilities for sample 7000 / 11550
# [t-SNE] Computed conditional probabilities for sample 8000 / 11550
# [t-SNE] Computed conditional probabilities for sample 9000 / 11550
# [t-SNE] Computed conditional probabilities for sample 10000 / 11550
# [t-SNE] Computed conditional probabilities for sample 11000 / 11550
# [t-SNE] Computed conditional probabilities for sample 11550 / 11550
# [t-SNE] Mean sigma: 0.072308
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.894150
# [t-SNE] KL divergence after 500 iterations: 1.509000
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\PC123\anaconda3\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
'timegan里的可视化  先取均值 再拼接 再做tsne的方法 比上面的多了取均值的过程'
def visualization2(ori, gen):
    
    Number = ori.shape[0]
    
    max_sample = min([4000, Number])       # 最多取4000个样本
    idx = np.random.permutation(Number)[ :max_sample]

    ori1 = np.asarray(ori)[idx]
    gen1 = np.asarray(gen)[idx]

    ori1 = np.mean(ori1, 2) 
    gen1 = np.mean(gen1, 2) 


    '上部分为原样本 下部分为生成样本'
    concat_data = np.concatenate((ori1, gen1), axis=0)
    
    pca = PCA(2)     
    pca_res = pca.fit_transform(concat_data)

    tsne = TSNE(n_components=2, verbose=1, perplexity=40,random_state=20,n_iter=500) 
    tsne_res = tsne.fit_transform(concat_data) 

    umap_ = umap.UMAP(random_state=42)
    umap_res = umap_.fit_transform(concat_data)
    
    
    fig = plt.figure(figsize=(19,4))
    plt.subplot(1,4,1)
    
    '0到2000索引的为原样本'
    plt.scatter(pca_res[:2000,0],pca_res[:2000,1], s=15, c='#ff7f0e')
    plt.scatter(pca_res[max_sample:max_sample+2000,0],pca_res[max_sample:max_sample+2000,1], s=15, c='#1f77b4')
    plt.xlabel('(a)',fontsize=25)
    
    plt.subplot(1,4,2)
    plt.scatter(tsne_res[:2000,0],tsne_res[:2000,1],  s=15,  c='#ff7f0e')
    plt.scatter(tsne_res[max_sample:max_sample+2000,0],tsne_res[max_sample:max_sample+2000,1], s=15, c='#1f77b4')
    plt.xlabel('(b)',fontsize=25)

    plt.subplot(1,4,3)
    plt.scatter(umap_res[:2000, 0], umap_res[:2000, 1],  cmap='Spectral', s=15,  c='#ff7f0e')
    plt.scatter(umap_res[max_sample:max_sample+2000, 0], umap_res[max_sample:max_sample+2000, 1],  cmap='Spectral', s=15, c='#1f77b4')
    plt.xlabel('(c)',fontsize=25)

    
    plt.subplot(1,4,4)
    sns.distplot(ori[:,:,1], hist=False, color = '#ff7f0e' )
    sns.distplot(gen[:,:,1], hist=False, color = '#1f77b4' )  
    plt.xlabel('(d)',fontsize=25)
    
    
#     plt.savefig('pca等合成图1111',dpi=500, bbox_inches='tight' )
#     plt.savefig('pca等合成图_sp5001111.pdf', bbox_inches='tight')

# %%
ori = training_data.cpu()
gen = X.permute(0, 2, 1).cpu().numpy()
visualization2(ori, gen)
# Out:
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8000 samples in 0.001s...
# [t-SNE] Computed neighbors for 8000 samples in 0.292s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8000
# [t-SNE] Computed conditional probabilities for sample 2000 / 8000
# [t-SNE] Computed conditional probabilities for sample 3000 / 8000
# [t-SNE] Computed conditional probabilities for sample 4000 / 8000
# [t-SNE] Computed conditional probabilities for sample 5000 / 8000
# [t-SNE] Computed conditional probabilities for sample 6000 / 8000
# [t-SNE] Computed conditional probabilities for sample 7000 / 8000
# [t-SNE] Computed conditional probabilities for sample 8000 / 8000
# [t-SNE] Mean sigma: 0.049451
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.150528
# [t-SNE] KL divergence after 500 iterations: 1.553627
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\PC123\anaconda3\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
'----------Reflow-----------'

import torch
from torch.nn import functional as F
from torch.distributions.normal import Normal


def flow_matching_loss(student_model, x_0, x_1, t, encoder_hidden_states):
    t = t.reshape((t.shape[0], 1, 1, 1))
    x_t = t * x_1 + (1 - t) * x_0
    t = t.flatten()
    
    student_pred = student_model(x_t, t, encoder_hidden_states=encoder_hidden_states).sample
    
    return F.mse_loss(student_pred, (x_1 - x_0), reduction="mean")


'欧拉采样过程 需要搞清楚x0和x1分别是什么'
'按照下面的流程的话x0应该是退化图像'
def sample_x1(unet, vae, x_0, encoder_hidden_states, n_steps: int = 100, device: str = "cuda"):
    unet.to(device)
    vae.to(device)
    unet.eval()
    vae.eval()
    
    x_t = x_0.to(device)
    bs = x_0.shape[0]
    eps = 1e-8         # t从一个很接近0的值开始
    t = torch.linspace(eps, 1 - eps, n_steps + 1).to(device)

    for i in range(1, len(t)):
        t_prev = t[i - 1].unsqueeze(0).repeat((bs,))

        with torch.no_grad():          # 计算速度
            f_eval = unet(x_t, t_prev, encoder_hidden_states=encoder_hidden_states).sample
            
        x_t = x_t + (t[i] - t[i - 1]) * f_eval   # xt加上时间间隔 dt乘以预测的速度
    
    return x_t


# t = torch.sigmoid(torch.randn((bs,), device=device))         # 随机的t
# torch.nn.utils.clip_grad_norm_(student_unet.parameters(), 1.0)

# %%
'制作退化数据集 用于训练reflow 要增加泛化性需要增加数据量'
'这里选择缺失数据的加噪值作为采样起点'
training_data = np.load(trainset_config['train_data_path'])
np.random.shuffle(training_data)
print(training_data.shape)

training_data = torch.from_numpy(training_data).float().cuda()


size = (Number, Length, Attribute )
noise = std_normal(size)

# mask = get_mask_rm( noise[0], 9)      # 原数据乘以缺失掩码
# mask = get_mask_mnr( X_0[0], 9) 
# mask = get_mask_bm( X_0[0], 9) 
Mask = get_mask_mcar( noise[0], 0.3)

print( torch.sum(Mask.eq(1)) )

Mask = Mask.repeat(noise.size()[0], 1, 1).float().cuda()
print(Mask.shape)


np.random.shuffle(training_data)


X_0_hat = training_data.reshape(-1, Length, Attribute)*Mask
# print(X_0_hat.shape)
# print(X_0_hat[0])
# print(mask[0])
# print(mask[10])

alpha_hat = Alpha_bar[T_acc - 1].reshape(-1, 1, 1).cuda() 
X_T_acc = ddpm_x0_to_xt(X_0_hat, alpha_hat, noise)     # 采样起点
print(X_T_acc.shape)

# x = x.permute(0, 2, 1)
# print(x.shape)
# Out:
# (5775, 30, 6)
# tensor(126)
# torch.Size([5775, 30, 6])
# torch.Size([5775, 30, 6])
# C:\Users\PC123\AppData\Local\Temp\ipykernel_580\2460368153.py:24: UserWarning: you are shuffling a 'Tensor' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(training_data)

# %%
# np.random.shuffle(xT_acc)
print(X_T_acc.shape)
# print(training_data[0])

dl_X_T_acc = torch.split( torch.tensor(X_T_acc),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
print(len(dl_X_T_acc), dl_X_T_acc[3].shape, dl_X_T_acc[-1].shape)           # 最后一个batch样本数可能会少一些
print(dl_X_T_acc[0][0][0:2])


dl_X_0_hat = torch.split( torch.tensor(X_0_hat),split_size_or_sections=128)
dl_Mask = torch.split( torch.tensor(Mask),split_size_or_sections=128)
# Out:
# torch.Size([5775, 30, 6])
# 46 torch.Size([128, 30, 6]) torch.Size([15, 30, 6])
# tensor([[ 0.0075, -0.0890, -1.1757, -1.4820, -0.5111, -0.8198],
#         [ 0.6909,  0.6890,  0.6912,  0.0878,  0.6386,  0.6933]],
#        device='cuda:0')
# C:\Users\PC123\AppData\Local\Temp\ipykernel_580\240688841.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_X_T_acc = torch.split( torch.tensor(X_T_acc),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
# C:\Users\PC123\AppData\Local\Temp\ipykernel_580\240688841.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_X_0_hat = torch.split( torch.tensor(X_0_hat),split_size_or_sections=128)
# C:\Users\PC123\AppData\Local\Temp\ipykernel_580\240688841.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_Mask = torch.split( torch.tensor(Mask),split_size_or_sections=128)

# %%
'教师模型用于生成ddim数据'

gc.collect()
torch.cuda.empty_cache()

teacher_unet = SSSDS4Imputer(**model_config).cuda()
teacher_unet.load_state_dict(torch.load( "./results/sp500_resfusion_mcar0.3.pth") )
# teacher_unet.load_state_dict(torch.load( "./results/ETTh1_resfusion_mcar0.3.pth") )
# teacher_unet.load_state_dict(torch.load( "./results/energy_resfusion_mcar0.3.pth") )
# teacher_unet.load_state_dict(torch.load( "./results/mujoco_resfusion_mcar0.3.pth") )

teacher_unet.eval()       


'学生模型可训练'
student_unet = SSSDS4Imputer(**model_config).cuda()
student_unet.load_state_dict(torch.load( "./results/sp500_resfusion_mcar0.3.pth"))
# student_unet.load_state_dict(torch.load( "./results/ETTh1_resfusion_mcar0.3.pth") )
# student_unet.load_state_dict(torch.load( "./results/energy_resfusion_mcar0.3.pth") )
# student_unet.load_state_dict(torch.load( "./results/mujoco_resfusion_mcar0.3.pth") )

student_unet.train()       

'变化学习率的话 最终结果差不多 小学习率的loss曲线更稳定 收敛好像也更快'
optimizer = torch.optim.Adam(student_unet.parameters())
# optimizer = torch.optim.Adam(student_unet.parameters(), lr=1e-4)  # 用这个学习率的话 用ddim训练reflow的loss波动性会更小 对ddpm的影响好像不大

# %%
'两种采样器生成退化数据x0对应的x1  ddpm和ddim 然后用于reflow'
'用ddim的生成数据进行reflow训练 loss可以达到0.001以下 最低0.0006左右  ddpm是0.006左右'
'从pca等效果来看 用ddim后reflow 采样结果更好'
'应该是因为ddim的确定性特点 适合整流法的确定性特点'
X = X_T_acc.permute(0, 2, 1)
trajectory_ddpm = []
with torch.no_grad():      
    for t in range(T_acc - 1, -1, -1):     
        
        trajectory_ddpm.append(X)

        diffusion_steps = (t * torch.ones((X.shape[0], 1))).cuda()    
              
        epsilon_theta = teacher_unet((X, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), diffusion_steps,)) 
#         epsilon_theta = teacher_unet((x, None, None, diffusion_steps,)) 
        
          
        alpha = Alpha[t].reshape(-1, 1, 1).cuda() 
        beta = Beta[t].reshape(-1, 1, 1).cuda() 
        alpha_hat = Alpha_bar[t].reshape(-1, 1, 1).cuda()      
        sigma = Sigma[t].reshape(-1, 1, 1).cuda()      

        X = (X - (1 - alpha) / torch.sqrt(1 - alpha_hat) * epsilon_theta) / torch.sqrt(alpha)
        if t > 0:
            X = X + sigma * std_normal( X.shape )    # x0不加标准差  add the variance term to x_{t-1}
    
    
trajectory_ddpm.append(X)
X_ddpm = X



# X = X_T_acc.permute(0, 2, 1)
# trajectory_ddim = []
# with torch.no_grad():      
#     for t in range(T_acc - 1, 0, -1):     
        
#         trajectory_ddim.append(X)

#         diffusion_steps = (t * torch.ones((X.shape[0], 1))).cuda()    
        
        
#         epsilon_theta = teacher_unet((X, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), diffusion_steps,)) 
# #         epsilon_theta = teacher_unet((x, None, None, diffusion_steps,)) 
        
        
#         alpha_hat = Alpha_bar[t].reshape(-1, 1, 1).cuda()      
#         alpha_hat_t_minus_1 = Alpha_bar[t-1].reshape(-1, 1, 1).cuda() 

#         X = ( torch.sqrt( alpha_hat_t_minus_1 ) * (X - torch.sqrt(1-alpha_hat) * epsilon_theta) ) / torch.sqrt(alpha_hat) + \
#                                                                                               torch.sqrt(1-alpha_hat_t_minus_1)* epsilon_theta
        
# trajectory_ddim.append(X)
# X_ddim = X

# %%
X_1_gen = X_ddpm
# X_1_gen = X_ddim

dl_X_1_gen = torch.split( torch.tensor(X_1_gen),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
print(len(dl_X_1_gen), dl_X_1_gen[3].shape, dl_X_1_gen[-1].shape)           # 最后一个batch样本数可能会少一些
print(dl_X_1_gen[0][0][0:2])
# Out:
# 46 torch.Size([128, 6, 30]) torch.Size([15, 6, 30])
# tensor([[0.9543, 0.9594, 0.9650, 0.9442, 0.9522, 0.9776, 0.9759, 0.9817, 0.9897,
#          0.9772, 0.9745, 0.9640, 0.9546, 0.9462, 0.9546, 0.9740, 0.9630, 0.9587,
#          0.9681, 0.9646, 0.9624, 0.9541, 0.9334, 0.8977, 0.8840, 0.8801, 0.8570,
#          0.8518, 0.8378, 0.8416],
#         [0.9784, 0.9799, 0.9751, 0.9530, 0.9715, 0.9844, 0.9948, 0.9853, 1.0005,
#          0.9965, 0.9945, 0.9852, 0.9828, 0.9721, 0.9624, 0.9784, 0.9755, 0.9669,
#          0.9837, 0.9794, 0.9767, 0.9732, 0.9506, 0.9253, 0.9127, 0.8917, 0.8848,
#          0.8679, 0.8504, 0.8526]], device='cuda:0')
# C:\Users\PC123\AppData\Local\Temp\ipykernel_14460\2415240420.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_X_1_gen = torch.split( torch.tensor(X_1_gen),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖

# %%
'第一种1训练reflow方法 提前利用退化数据x0 计算好对应的x1 再进行reflow训练'

print(T_acc)
# min_step_percent=0.02
# max_step_percent=0.98
min_step_percent=0
max_step_percent=1

min_step = int( T_acc * min_step_percent)
max_step = int( T_acc * max_step_percent)

iters=0   
reflow_epoch=30       # reflow训练次数

print(min_step, max_step)

loss_list = []
# Out:
# 166
# 0 166

# %%
while iters < reflow_epoch + 1:         
    for i in range(0, len(dl_X_T_acc)):
    
        x_0 = dl_X_T_acc[i].float().cuda()  # [128, 6, 30] 缺失数据的加噪值 采样起点
        x_1 = dl_X_1_gen[i].float().cuda()  # [128, 6, 30] 原数据
        x_0_hat = dl_X_0_hat[i].float().cuda()  # 缺失数据  作为条件
        mask = dl_Mask[i].float().cuda()
        
        B = x_0.shape[0]
        
        
        '开始整流加噪'
        t = torch.randint(min_step, max_step + 1, (x_0.shape[0],) ).cuda()          
        t_view = t.view(B, 1, 1)
        x_t = ( t_view/T_acc ) * x_1 + ( 1-t_view/T_acc ) * x_0.permute(0, 2, 1) # 整流加噪时t缩放到0-1
        
        '预测时t的2个使用方式  可以用离散的 也可以转换为0-1再用  第一个方法收敛更快' 
        pred_v = student_unet( (x_t, x_0_hat.permute(0, 2, 1), mask.permute(0, 2, 1), t.view(B, 1),) )   
#         pred_v = student_unet( (x_t, None, None, t.view(B, 1),) )   
        
        
#         pred_v = student_unet( (x_t, 1, 1, t.view(B, 1)/T_acc,) )  
             
        
        '注意loss里x0和x1的位置  用x0-x1时loss很小 可达0.002以下 可收敛 到后面会缓慢减小'
        '用x1-x0时loss较大 为0.7多一点 也可以收敛'
#         loss = F.mse_loss(pred_v, (X_1 - X_0.permute(0, 2, 1) ), reduction="mean")
#         loss = F.mse_loss(pred_v, (X_1 - X_0.permute(0, 2, 1) ))
#         loss = F.mse_loss(pred_v, ( X_0.permute(0, 2, 1)- X_1 ), reduction="mean")
        loss = F.mse_loss(pred_v, ( x_0.permute(0, 2, 1)- x_1 ))
        
        optimizer.zero_grad()
        loss.backward()
#         torch.nn.utils.clip_grad_norm_(student_unet.parameters(), 1.0)
        optimizer.step()
#         print(loss.item())
        
        loss_list.append(loss.item())
           
    iters += 1

# %%
print(len(loss_list))

loss_ddpm = loss_list
# loss_ddim = loss_list


# plt.figure()
# plt.plot(loss_ddpm)
# plt.plot(loss_ddim)

plt.figure()
plt.plot(loss_ddpm[10:],label='Reflow by DDPM' )
plt.plot(loss_ddim[10:],label='Reflow by DDIM')
plt.legend()



rmse1 = list( map(lambda x: x ** (1/2), loss_ddpm) )
rmse2 = list( map(lambda x: x ** (1/2), loss_ddim) )


plt.figure()
plt.plot(rmse1[10:],label='Reflow by DDPM')
plt.plot(rmse2[10:],label='Reflow by DDIM')
plt.xlabel('Iteration',fontsize=13)
plt.legend()

# plt.savefig('loss对比',dpi=500)
# plt.savefig('loss对比.pdf')
# Out:
# 1426

# %%
'保存和导入reflow模型参数'
'reflow模型效果足够好 不需要重复训练 直接用以前的即可'
'当前可以训练来看loss等中间结果 最终的参数不用保存 用以前的即可'
gc.collect()
torch.cuda.empty_cache()

# torch.save( student_unet.state_dict(),"./results/sp500_reflow_mcar0.3.pth" )
# torch.save( student_unet.state_dict(),"./results/ETTh1_reflow_mcar0.3.pth" )
# torch.save( student_unet.state_dict(),"./results/energy_reflow_mcar0.3.pth" )
# torch.save( student_unet.state_dict(),"./results/mujoco_reflow_mcar0.3.pth" )


student_unet = SSSDS4Imputer(**model_config).cuda()
student_unet.load_state_dict(torch.load( "./results/sp500_reflow_mcar0.3.pth" ))
# student_unet.load_state_dict(torch.load( "./results/ETTh1_reflow_mcar0.3.pth" ))
# student_unet.load_state_dict(torch.load( "./results/energy_reflow_mcar0.3.pth" ))
# student_unet.load_state_dict(torch.load( "./results/mujoco_reflow_mcar0.3.pth" ))
# Out:
# <All keys matched successfully>

# %%
'第二种训练reflow方式 训练时利用退化数据x0来生成需要的x1 再进行reflow'
'这种方法训练速度慢'

# while iters < n_iters + 1:         
#     for batch in dl_xT_acc:
        
#         X_0 = batch.float().cuda()  # [128, 30, 6]
#         B = X_0.shape[0]
           
#         x = X_0.permute(0, 2, 1)  # [128, 6, 30]

    
'先用退化数据集生成原数据x1'
'两个减噪方式产生的x1 在之后reflow计算loss 照理来说应该是ddim更好 ddim的loss最低可以到0.01 ddpm高一些 '
#         with torch.no_grad():      
#             for t in range(T_acc - 1, -1, -1):       

#                 diffusion_steps = (t * torch.ones((x.shape[0], 1))).cuda()    
#                 epsilon_theta = teacher_unet((x, 1, 1, diffusion_steps,)) 
#                 alpha = Alpha[t].reshape(-1, 1, 1).cuda() 
#                 beta = Beta[t].reshape(-1, 1, 1).cuda() 
#                 alpha_hat = Alpha_bar[t].reshape(-1, 1, 1).cuda()      
#                 sigma = Sigma[t].reshape(-1, 1, 1).cuda()      

#                 x = (x - (1 - alpha) / torch.sqrt(1 - alpha_hat) * epsilon_theta) / torch.sqrt(alpha)
#                 if t > 0:
#                     x = x + sigma * std_normal( x.shape )    # x0不加标准差  add the variance term to x_{t-1}
                    
                     
#         with torch.no_grad():      
#             for t in range(T_acc - 1, 0, -1):       

#                 diffusion_steps = (t * torch.ones((x.shape[0], 1))).cuda()        
#                 epsilon_theta = teacher_unet((x, 1, 1, diffusion_steps,)) 
#                 alpha_hat = Alpha_bar[t].reshape(-1, 1, 1).cuda()      
#                 alpha_hat_t_minus_1 = Alpha_bar[t-1].reshape(-1, 1, 1).cuda() 

#                 x = ( torch.sqrt( alpha_hat_t_minus_1 ) * (x - torch.sqrt(1-alpha_hat) * epsilon_theta) ) / torch.sqrt(alpha_hat) + \
#                                                                                                   torch.sqrt(1-alpha_hat_t_minus_1)* epsilon_theta

                    
#         X_1 = x                         # [128, 6, 30]

#         '开始整流加噪'
#         t = torch.randint(min_step, max_step + 1, (X_0.shape[0],) ).cuda()          
#         t_view = t.view(B, 1, 1)
#         x_t = ( t_view/T_acc ) * X_1 + ( 1-t_view/T_acc ) * X_0.permute(0, 2, 1)   # 整流加噪时t缩放到0-1
        
#         '预测时t的2个使用方式  可以用离散的 也可以转换为0-1再用  第一个方法收敛更快'
#         pred_v = student_unet( (x_t, 1, 1, t.view(B, 1),) )   
# #         pred_v = student_unet( (x_t, 1, 1, t.view(B, 1)/T_acc,) )  
             
        
#         '注意loss里x0和x1的位置  用x0-x1时loss很小 可收敛 用x1-x0时loss较大 为0.7多一点 也可以收敛'
# #         loss = F.mse_loss(pred_v, (X_1 - X_0.permute(0, 2, 1) ), reduction="mean")
# #         loss = F.mse_loss(pred_v, (X_1 - X_0.permute(0, 2, 1) ))
# #         loss = F.mse_loss(pred_v, ( X_0.permute(0, 2, 1)- X_1 ), reduction="mean")
#         loss = F.mse_loss(pred_v, ( X_0.permute(0, 2, 1)- X_1 ))
        
#         optimizer.zero_grad()
#         loss.backward()
# #         torch.nn.utils.clip_grad_norm_(student_unet.parameters(), 1.0)
#         optimizer.step()
#         print(loss)
        
#         loss_list.append(loss.item())
# Out:
# '两个减噪方式产生的x1 在之后reflow计算loss 照理来说应该是ddim更好 ddim的loss最低可以到0.01 ddpm高一些 '

# %%
# print(len(loss_list))

# plt.figure()
# plt.plot(loss_list)

# %%
'reflow之后采样'    
'采样时采样步只要几步左右 就和100左右的效果类似'
'此时t=1结果也很好 可以不用蒸馏'
     
student_unet.cuda()
student_unet.eval()


'用新的数据集计算reflow   制作退化数据集'
'这里选择缺失数据的加噪值作为采样起点'
training_data = np.load(trainset_config['train_data_path'])
np.random.shuffle(training_data)
print(training_data.shape)

training_data = torch.from_numpy(training_data).float().cuda()


size = (Number, Length, Attribute )

noise = std_normal(size)

# mask = get_mask_rm( noise[0], 9)      # 原数据乘以缺失掩码
# mask = get_mask_mnr( X_0[0], 9) 
# mask = get_mask_bm( X_0[0], 9) 
Mask = get_mask_mcar( noise[0], 0.3)

print( torch.sum(Mask.eq(1)) )

Mask = Mask.repeat(noise.size()[0], 1, 1).float().cuda()
print(Mask.shape)


np.random.shuffle(training_data)


X_0_hat = training_data.reshape(-1, Length, Attribute)*Mask
# print(X_0_hat.shape)
# print(X_0_hat[0])
# print(mask[0])
# print(mask[10])

alpha_hat = Alpha_bar[T_acc - 1].reshape(-1, 1, 1).cuda() 
X_T_acc = ddpm_x0_to_xt(X_0_hat, alpha_hat, noise)     # 采样起点
print(X_T_acc.shape)

# x = x.permute(0, 2, 1)
# print(x.shape)
# Out:
# (5775, 30, 6)
# tensor(126)
# torch.Size([5775, 30, 6])
# torch.Size([5775, 30, 6])
# C:\Users\PC123\AppData\Local\Temp\ipykernel_580\2924498179.py:33: UserWarning: you are shuffling a 'Tensor' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(training_data)

# %%
X_t = X_T_acc.permute(0, 2, 1).cuda()
bs = X_t.shape[0]
print(X_t.shape)

# eps = 1e-8         # t从一个很接近0的值开始
# eps = 0.02
eps = 0
n_steps = 30       # reflow采样步

t = torch.linspace(eps, 1 - eps, n_steps + 1).cuda()
t = t * T_acc 
t= t.int()
print(t)
print(t.shape)
# print(t.view(101,1,1).shape)


t0 = t[0] * torch.ones((X_t.shape[0], 1)).cuda()
print( t0.shape )
# print(t[100])

# t =list(map(int,t))
# Out:
# torch.Size([5775, 6, 30])
# tensor([  0,   5,  11,  16,  22,  27,  33,  38,  44,  49,  55,  60,  66,  71,
#          77,  83,  88,  94,  99, 105, 110, 116, 121, 127, 132, 138, 143, 149,
#         154, 160, 166], device='cuda:0', dtype=torch.int32)
# torch.Size([31])
# torch.Size([5775, 1])

# %%
start_time = time.time()

trajectory_reflow = []
for i in range(1, len(t)):
    
    trajectory_reflow.append(X_t)

    t_prev = t[i - 1]
    t_prev = t_prev * torch.ones((X_t.shape[0], 1)).cuda()   # [5775, 1])
#     print(t[i].shape, t_prev.shape)
    
    with torch.no_grad():          # 计算速度

        
        pred_v = student_unet( (X_t, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), t_prev.view(bs, 1),) )   
        
#         pred_v = student_unet( (x_t, None, None, t_prev.view(bs, 1),) )   
        
        
#     t_prev = t_prev.view(bs, 1, 1)
#     t_i = t[i] * torch.ones((x_t.shape[0], 1)).cuda() 
#     t_i = t_i.view(bs, 1, 1)
    

    X_t = X_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 
#     x_t = x_t + ( ( t_prev - t_i )/T_acc ) * pred_v 
#     x_t = x_t + ( t[i] - t[i - 1]) * pred_v   # xt加上时间间隔 dt乘以预测的速度
#     x_t = x_t + (t[i-1] - t[i]) * pred_v 

print(X_t.shape)

trajectory_reflow.append(X_t)


end_time = time.time()
execution_time = end_time - start_time   # 数据集遍历完一次的时间  sp500差不多9.5s
print(execution_time)
# Out:
# torch.Size([5775, 6, 30])
# 29.17545795440674

# %%
'--------RMSE--------'
gt = training_data
result = X_t.permute(0, 2, 1)


loss = nn.MSELoss()
# output1 = loss(input=result, target=gt)
# output2 = loss(input=result*Mask, target=gt*Mask)                 # 观测位置的mse
# output3 = loss(input=result*Mask, target=X_0_hat*Mask )             
output4 = loss(input=result*(1-Mask), target=gt*(1-Mask)  )       # 缺失位置的mse  最重要的指标
# output5 = loss(input=result[0:1000]*(1-Mask[0:1000]), target=gt[0:1000]*(1-Mask[0:1000])  ) 
# output6 = loss(input=result*(1-Mask), target=X_0_hat*(1-Mask) )    

# print(output1, torch.sqrt(output1))
# print(output2, torch.sqrt(output2))
# print(output3, torch.sqrt(output3))
print(output4, torch.sqrt(output4))
# print(output5, torch.sqrt(output5))
# print(output6, torch.sqrt(output6))
# Out:
# tensor(0.0001, device='cuda:0') tensor(0.0116, device='cuda:0')

# %%
'制作reflow数据集'
# X_1_reflow = X_t.permute(0, 2, 1)

# dl_X_1_reflow = torch.split( torch.tensor(X_1_reflow),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
# print(len(dl_X_1_reflow), dl_X_1_reflow[3].shape, dl_X_1_reflow[-1].shape)           # 最后一个batch样本数可能会少一些
# print(dl_X_1_reflow[0][0][0:2])
# Out:
# '制作reflow数据集'

# %%
ori = training_data.cpu()
gen = X_t.permute(0, 2, 1).cpu().numpy()
# visualization1(ori, gen)
visualization2(ori, gen)
# Out:
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8000 samples in 0.000s...
# [t-SNE] Computed neighbors for 8000 samples in 0.191s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8000
# [t-SNE] Computed conditional probabilities for sample 2000 / 8000
# [t-SNE] Computed conditional probabilities for sample 3000 / 8000
# [t-SNE] Computed conditional probabilities for sample 4000 / 8000
# [t-SNE] Computed conditional probabilities for sample 5000 / 8000
# [t-SNE] Computed conditional probabilities for sample 6000 / 8000
# [t-SNE] Computed conditional probabilities for sample 7000 / 8000
# [t-SNE] Computed conditional probabilities for sample 8000 / 8000
# [t-SNE] Mean sigma: 0.019083
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.855682
# [t-SNE] KL divergence after 500 iterations: 1.153307
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\PC123\anaconda3\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
'随机取一个样本的像素点 两个列表随机产生  并确定取的个数'
'也可以随机取一定个数的样本 每个样本取均值 画图 '
'第一个方法属于取一个样本里像素点的轨迹 所以取最后曲线会集于一点 第二个属于取多个样本的轨迹 曲线应该不会集中 把几个图里的0索引换成其他的随机值'
num_trajectories = 10
indices_x = np.random.choice(trajectory_reflow[0][0].shape[0], num_trajectories)    # 一个样本的行和列里面选像素
indices_y = np.random.choice(trajectory_reflow[0][0].shape[1], num_trajectories)


indices_sample = np.random.choice(trajectory_reflow[0].shape[0], num_trajectories)  # 在样本数5775里面选一个样本


time1 = range(0,len(trajectory_ddpm))
value1 = []
for i in range(len(trajectory_ddpm)):
    value1.append( trajectory_ddpm[i][ 0, indices_x, indices_y ].cpu() )

    
time2 = range(0,len(trajectory_ddim))
value2 = []
for i in range(len(trajectory_ddim)):
    value2.append( trajectory_ddim[i][ 0, indices_x, indices_y ].cpu() )


time3 = range(0,len(trajectory_reflow))
value3 = []
for i in range(len(trajectory_reflow)):
    value3.append( trajectory_reflow[i][ 0, indices_x, indices_y ].cpu() )


plt.figure(figsize=(9, 4))
plt.subplot(2,3,1)
plt.plot( time1, value1)
plt.subplot(2,3,2)
plt.plot( time2, value2)
plt.subplot(2,3,3)
plt.plot( time3, value3)



'随机取样本 计算样本的轨迹'

time4 = range(0,len(trajectory_ddpm))
value4 = []
for i in range(len(trajectory_ddpm)):
    value = trajectory_ddpm[i][indices_sample]
    value = value.mean(2).mean(1)
    value4.append(value.cpu())

    
time5 = range(0,len(trajectory_ddim))
value5 = []
for i in range(len(trajectory_ddim)):
    value = trajectory_ddim[i][indices_sample]
    value = value.mean(2).mean(1)
    value5.append(value.cpu())

time6 = range(0,len(trajectory_reflow))
value6 = []
for i in range(len(trajectory_reflow)):
    value = trajectory_reflow[i][indices_sample]
    value = value.mean(2).mean(1)
    value6.append(value.cpu())


# plt.subplot(2,3,4)
# plt.plot( time4, value4)
# plt.subplot(2,3,5)
# plt.plot( time5, value5)
# plt.subplot(2,3,6)
# plt.plot( time6, value6)

# plt.savefig('trajectory1',bbox_inches='tight',dpi=500)
# Out:
# '第一个方法属于取一个样本里像素点的轨迹 所以取最后曲线会集于一点 第二个属于取多个样本的轨迹 曲线应该不会集中 把几个图里的0索引换成其他的随机值'

# %%
from scipy.integrate import quad

# 计算两个值之间的速度  用两个值之差 除以时间间隔 得到速度  
def compute_velocity(z_t, z_t_minus_1, delta_t):
    v_t = (z_t_minus_1 - z_t) / delta_t
    return v_t
                         # (248, 1, 4, 32, 32)  上面的函数     false
def straightness_measurement(Z_t_list, compute_velocity, use_velocity_fn):
    """
    Measure the straightness of a trajectory given initial and final positions (Z_0, Z_1)
    and a velocity function v(Z_t, t).
    """

#     Z_0 = Z_t_list[0]   # 估计的起点和终点
#     Z_1 = Z_t_list[-1]
    
    
    Z_0 = Z_t_list[-1]   # 修改方向 这个要改的话  上面的compute_velocity里的两个相减的值就不用换位置
    Z_1 = Z_t_list[0]
    

    def integrand(t):
        # t is [0, 1], we must scale it to the length of Z_t_list
        i = t * (len(Z_t_list) - 1)
        delta_t = 1 / len(Z_t_list) # 时间间隔 for now we assume linearly spaced time steps

        if use_velocity_fn:            # 当前为false 不用额外计算向量
            if t == 0:
                v_t = 0
            else:                  # 计算相邻两点直接的速度
                v_t = compute_velocity(Z_t_list[int(i)], Z_t_list[int(i-1)], delta_t)  
        else:
            v_t = Z_t_list[int(i)]     # 直接取向量值
            
        deviation = (Z_1 - Z_0) - v_t
        deviation = np.array(deviation.cpu())  #要转换成np格式才好进行下面的取均值计算
        
        return np.mean(deviation ** 2)

    # Integrate from t=0 to t=1
    S_Z, _ = np.log(quad(integrand, 0, 1))
    return S_Z


straightness_value_ddpm = straightness_measurement( trajectory_ddpm, compute_velocity, use_velocity_fn=True)
straightness_value_ddim = straightness_measurement( trajectory_ddim, compute_velocity, use_velocity_fn=True)
straightness_value_reflow = straightness_measurement( trajectory_reflow, compute_velocity, use_velocity_fn=True)
print(straightness_value_ddpm, straightness_value_ddim, straightness_value_reflow )
# Out:
# C:\Users\PC123\AppData\Local\Temp\ipykernel_8868\3856962783.py:41: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   S_Z, _ = np.log(quad(integrand, 0, 1))
# 5.449200331148091 -2.688898736161439 -3.4020322734757835

# %%
models = ["DDPM", "DDIM", 'Reflow']
s_value = [straightness_value_ddpm, straightness_value_ddim, straightness_value_reflow ]

plt.figure(figsize=(12,4))

plt.subplot(1,4,1)
plt.plot(models, s_value,'o--',  linewidth=1, markersize=4)
plt.ylabel('log S(Z)')


for i in range(len(models)-1):
    plt.text(i, s_value[i]+0.1, round(s_value[i],3))
plt.text(2-0.2, s_value[2]+0.1, round(s_value[2],3))
plt.xlabel('Sampler')
    
plt.title('(a)',fontsize=18, x=0.5, y=-0.25) 
    
    
    
plt.subplot(2,4,2)
plt.plot( time1, value1)
# plt.xlabel('Sampling step')
# plt.ylabel('Pixel Value')
plt.title('Trajectories - DDPM')

plt.subplot(2,4,3)
plt.plot( time2, value2)
plt.title('Trajectories - DDIM')

plt.subplot(2,4,4)
plt.plot( time3, value3)
plt.title('Trajectories - Reflow')


plt.subplot(2,4,6)
plt.plot( time4, value4)
plt.xlabel('Sampling step')

plt.subplot(2,4,7)
plt.plot( time5, value5)
plt.xlabel('Sampling step')

plt.title('(b)',fontsize=18, x=0.5, y=-0.55) 


plt.subplot(2,4,8)
plt.plot( time6, value6)
plt.xlabel('Sampling step')

# plt.tight_layout()
plt.savefig('trajectory2',bbox_inches='tight',dpi=500)
plt.savefig('trajectory2.pdf', bbox_inches='tight')

# %%
'--------instaflow里的简易蒸馏法---------'
'把上面reflow好的模型 作为基础 看成教师和学生模型'
'应该可以提前用reflow模型的生成数据  直接训练蒸馏 像训练reflow一样 防止一边蒸馏训练一边生成 减少计算时间'

gc.collect()
torch.cuda.empty_cache()

teacher_unet = SSSDS4Imputer(**model_config).cuda()
teacher_unet.load_state_dict(torch.load( "./results/sp500_reflow_mcar0.3.pth" ))
# teacher_unet.load_state_dict(torch.load( "./results/ETTh1_reflow_mcar0.3.pth" ))
# teacher_unet.load_state_dict(torch.load( "./results/energy_reflow_mcar0.3.pth" ))


student_unet = SSSDS4Imputer(**model_config).cuda()
student_unet.load_state_dict(torch.load( "./results/sp500_reflow_mcar0.3.pth" ))
# student_unet.load_state_dict(torch.load( "./results/ETTh1_reflow_mcar0.3.pth" ))
# student_unet.load_state_dict(torch.load( "./results/energy_reflow_mcar0.3.pth" ))


student_unet.cuda()
teacher_unet.cuda()


'学生模型可训练 教师模型固定'
student_unet.train()
teacher_unet.eval()
# optimizer = torch.optim.Adam(student_unet.parameters())
optimizer = torch.optim.Adam(student_unet.parameters(), lr=1e-4)
# optimizer = torch.optim.Adam(student_unet.parameters(), lr=1e-5)

# %%
'制作退化数据集'
'这里选择缺失数据的加噪值作为采样起点'
training_data = np.load(trainset_config['train_data_path'])
np.random.shuffle(training_data)
print(training_data.shape)

training_data = torch.from_numpy(training_data).float().cuda()


size = (Number, Length, Attribute )

noise = std_normal(size)

# mask = get_mask_rm( noise[0], 9)      # 原数据乘以缺失掩码
# mask = get_mask_mnr( X_0[0], 9) 
# mask = get_mask_bm( X_0[0], 9) 
Mask = get_mask_mcar( noise[0], 0.3)

print( torch.sum(Mask.eq(1)) )

Mask = Mask.repeat(noise.size()[0], 1, 1).float().cuda()
print(Mask.shape)


np.random.shuffle(training_data)


X_0_hat = training_data.reshape(-1, Length, Attribute)*Mask
# print(X_0_hat.shape)
# print(X_0_hat[0])
# print(mask[0])
# print(mask[10])

alpha_hat = Alpha_bar[T_acc - 1].reshape(-1, 1, 1).cuda() 
X_T_acc = ddpm_x0_to_xt(X_0_hat, alpha_hat, noise)     # 采样起点
print(X_T_acc.shape)

# x = x.permute(0, 2, 1)
# print(x.shape)
# Out:
# (5775, 30, 6)
# tensor(126)
# torch.Size([5775, 30, 6])
# torch.Size([5775, 30, 6])
# C:\Users\PC123\AppData\Local\Temp\ipykernel_14916\663328047.py:25: UserWarning: you are shuffling a 'Tensor' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(training_data)

# %%
dl_X_T_acc = torch.split( torch.tensor(X_T_acc),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
print(len(dl_X_T_acc), dl_X_T_acc[3].shape, dl_X_T_acc[-1].shape)           # 最后一个batch样本数可能会少一些
print(dl_X_T_acc[0][0][0:2])


dl_X_0_hat = torch.split( torch.tensor(X_0_hat),split_size_or_sections=128)
dl_Mask = torch.split( torch.tensor(Mask),split_size_or_sections=128)
# Out:
# 46 torch.Size([128, 30, 6]) torch.Size([15, 30, 6])
# tensor([[-0.0475, -0.0577,  0.2972,  1.7675,  0.3342, -1.1366],
#         [ 0.9422, -0.1718,  0.2767,  2.3036,  0.9050,  0.2805]],
#        device='cuda:0')
# C:\Users\PC123\AppData\Local\Temp\ipykernel_14916\3799018885.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_X_T_acc = torch.split( torch.tensor(X_T_acc),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
# C:\Users\PC123\AppData\Local\Temp\ipykernel_14916\3799018885.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_X_0_hat = torch.split( torch.tensor(X_0_hat),split_size_or_sections=128)
# C:\Users\PC123\AppData\Local\Temp\ipykernel_14916\3799018885.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_Mask = torch.split( torch.tensor(Mask),split_size_or_sections=128)

# %%
X_t = X_T_acc.permute(0, 2, 1).cuda()
print(X_t.shape)

reflow_step = 1
n_steps = 30
eps = 0
t = torch.linspace(eps, 1 - eps, n_steps + 1).cuda()
t = t * T_acc 
t= t.int()

print(X_t.shape, X_0_hat.shape, Mask.shape)
# Out:
# torch.Size([5775, 6, 30])
# torch.Size([5775, 6, 30]) torch.Size([5775, 30, 6]) torch.Size([5775, 30, 6])

# %%
'生成reflow数据集'
with torch.no_grad():  
    for i in range(1, len(t)):

        t_prev = t[i - 1]
        t_prev = t_prev * torch.ones((X_t.shape[0], 1)).cuda()   # [5775, 1])

        with torch.no_grad():          # 计算速度
            pred_v = teacher_unet( (X_t, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), t_prev.view(Number, 1),) )   

        X_t = X_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 

print(X_t.shape)



'制作reflow数据集'
X_1_reflow = X_t.permute(0, 2, 1)

dl_X_1_reflow = torch.split( torch.tensor(X_1_reflow),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
print(len(dl_X_1_reflow), dl_X_1_reflow[3].shape, dl_X_1_reflow[-1].shape)           # 最后一个batch样本数可能会少一些
print(dl_X_1_reflow[0][0][0:2])
# Out:
# torch.Size([5775, 6, 30])
# 46 torch.Size([128, 30, 6]) torch.Size([15, 30, 6])
# C:\Users\PC123\AppData\Local\Temp\ipykernel_14916\1534726861.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dl_X_1_reflow = torch.split( torch.tensor(X_1_reflow),split_size_or_sections=128) # 数据分割 每一份大小即batchsize为64个样本 最后一份为除不尽的余数 输出为元祖
# tensor([[0.3535, 0.3669, 0.0374, 0.3821, 0.3595, 0.3388],
#         [0.3728, 0.3739, 0.0424, 0.3950, 0.3739, 0.3598]], device='cuda:0')

# %%
gt = training_data
result = X_t.permute(0, 2, 1)


loss = nn.MSELoss()
output4 = loss(input=result*(1-Mask), target=gt*(1-Mask)  )       # 缺失位置的mse  最重要的指标
print(output4, torch.sqrt(output4))
# Out:
# tensor(0.0002, device='cuda:0') tensor(0.0127, device='cuda:0')

# %%
'提前计算好数据集 再蒸馏'

iters=0   
n_iters=200  # 蒸馏的epoch

'该值为1时就是一步生成了'
distill_step = 1   

loss_list = []

while iters < n_iters + 1:  
      
    for i in range(0, len(dl_X_T_acc)):
    
        x_0 = dl_X_T_acc[i].float().cuda().permute(0, 2, 1)  # [128, 6, 30] 缺失数据的加噪值 采样起点
        x_1_reflow = dl_X_1_reflow[i].float().cuda().permute(0, 2, 1)  # [128, 6, 30] 原数据
        x_0_hat = dl_X_0_hat[i].float().cuda().permute(0, 2, 1)  # 缺失数据  作为条件
        mask = dl_Mask[i].float().cuda().permute(0, 2, 1)
        
        x_t = x_0
        bs = x_t.shape[0]
        
        t = torch.linspace(eps, 1 - eps, distill_step + 1).cuda()
        t = t * T_acc 
        t = t.int()
        
        for i in range(1, len(t)):
            t_prev = t[i - 1]
            t_prev = t_prev * torch.ones((x_t.shape[0], 1)).cuda()   # [5775, 1])
            pred_v = student_unet( (x_t, x_0_hat, mask, t_prev.view(bs, 1),) )   
            x_t = x_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 
            
        res_student = x_t
        
        loss = F.mse_loss(res_student, x_1_reflow)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(loss)
        loss_list.append(loss.item())
        
    iters += 1
# Out:
# tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0547, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# ...
# tensor(8.7003e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.3470e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.3766e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9858e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8834e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8789e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.1125e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.5449e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.2385e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.1731e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9880e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.5690e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.3735e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.6541e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.7375e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.3113e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.2217e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.8564e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.4563e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9557e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7522e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7394e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.0506e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.5802e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.2441e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.2821e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8137e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7770e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9532e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.7777e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.7208e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.0630e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9618e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9814e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.1951e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.3348e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.1946e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.6440e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9707e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.4826e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.4887e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8915e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9677e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.4474e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.2881e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.8121e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7435e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8567e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.6436e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.1214e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.6287e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7070e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.2784e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.6084e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.0110e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.8990e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9296e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7872e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.6895e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.3425e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7404e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9830e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9865e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9945e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.3964e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.8308e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.5697e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8924e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.4003e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.4794e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.6610e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.8977e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9711e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.7419e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.8176e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.1194e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.0467e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.7369e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.4480e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8027e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.5615e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.2896e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.4566e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.4720e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7956e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.4131e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.7673e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.0201e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.5519e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9945e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.1677e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.1755e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.6716e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.3653e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.0205e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.3320e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.6192e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.9479e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.7548e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.0442e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.2534e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.5001e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.6593e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.2000e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7538e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.0689e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.7778e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.4210e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9786e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.9093e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.8579e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.7746e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.8447e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.4667e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.1315e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.9013e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.9608e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.4475e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(6.2796e-05, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
# '一边生成数据 一边蒸馏训练'
# iters=0   
# n_iters=10  # 蒸馏的epoch

# '该值为1时就是一步生成了'
# reflow_step = 1   

# loss_list = []

# while iters < n_iters + 1:         

#     for i in range(0, len(dl_X_T_acc)):
        
#         x_0 = dl_X_T_acc[i].float().cuda().permute(0, 2, 1) # [128, 6, 30] 缺失数据的加噪值 采样起点
# #         x_1 = dl_X_1_gen[i].float().cuda()  # [128, 6, 30] 原数据
#         x_0_hat = dl_X_0_hat[i].float().cuda().permute(0, 2, 1)  # 缺失数据  作为条件
#         mask = dl_Mask[i].float().cuda().permute(0, 2, 1)
        
#         x_t = x_0
#         bs = x_t.shape[0]

        
#         '教师模型的常规多步采样'
#         with torch.no_grad():   
#             for i in range(1, len(t)):
#                 t_prev = t[i - 1]
#                 t_prev = t_prev * torch.ones((x_t.shape[0], 1)).cuda()   # [5775, 1])

#                 with torch.no_grad():          # 计算速度
#                     pred_v = teacher_unet( (x_t, x_0_hat, mask, t_prev.view(bs, 1),) )   

#                 x_t = x_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 
            
#         res_teacher = x_t
            
        
#         '学生模型的一步采样 reflow_step为固定的步长 输入和教师模型相同 比较输出的mse'
#         x_t = x_0
        
#         t = torch.linspace(eps, 1 - eps, reflow_step + 1).cuda()
#         t = t * T_acc 
#         t = t.int()
        
#         for i in range(1, len(t)):
#             t_prev = t[i - 1]
#             t_prev = t_prev * torch.ones((x_t.shape[0], 1)).cuda()   # [5775, 1])
#             pred_v = student_unet( (x_t, x_0_hat, mask, t_prev.view(bs, 1),) )   
#             x_t = x_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 
            
#         res_student = x_t
        
#         loss = F.mse_loss(res_student, res_teacher)
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
#         print(loss)
#         loss_list.append(loss.item())
        
#     iters += 1

# %%
print(len(loss_list))

plt.figure()
plt.plot(loss_list[10:])


rmse = list( map(lambda x: x ** (1/2), loss_list) )
plt.figure()
plt.plot(rmse[20:])
# Out:
# 4646

# %%
'保存蒸馏模型'
torch.save( student_unet.state_dict(),"./results/sp500_distill_mcar0.3.pth" )
# torch.save( student_unet.state_dict(),"./results/ETTh1_distill_mcar0.3.pth" )
# torch.save( student_unet.state_dict(),"./results/energy_distill_mcar0.3.pth" )
# torch.save( student_unet.state_dict(),"./results/mujoco_distill_mcar0.3.pth" )


'测试蒸馏后的一步采样结果'
gc.collect()
torch.cuda.empty_cache()

distill_unet = SSSDS4Imputer(**model_config).cuda()
distill_unet.load_state_dict(torch.load( "./results/sp500_distill_mcar0.3.pth" ))
# distill_unet.load_state_dict(torch.load( "./results/ETTh1_distill_mcar0.3.pth" ))
# distill_unet.load_state_dict(torch.load( "./results/energy_distill_mcar0.3.pth" ))
# distill_unet.load_state_dict(torch.load( "./results/mujoco_distill_mcar0.3.pth" ))

distill_unet.eval()


reflow_unet = SSSDS4Imputer(**model_config).cuda()
reflow_unet.load_state_dict(torch.load( "./results/sp500_reflow_mcar0.3.pth" ))
# reflow_unet.load_state_dict(torch.load( "./results/ETTh1_reflow_mcar0.3.pth" ))
# reflow_unet.load_state_dict(torch.load( "./results/energy_reflow_mcar0.3.pth" ))
# reflow_unet.load_state_dict(torch.load( "./results/mujoco_reflow_mcar0.3.pth" ))


reflow_unet.eval()
# Out:
# SSSDS4Imputer(
#   (init_conv): Sequential(
#     (0): Conv(
#       (conv): Conv1d(6, 128, kernel_size=(1,), stride=(1,))
#     )
#     (1): ReLU()
#   )
#   (residual_layer): Residual_group(
#     (fc_t1): Linear(in_features=128, out_features=512, bias=True)
#     (fc_t2): Linear(in_features=512, out_features=512, bias=True)
#     (residual_blocks): ModuleList(
#       (0): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (1): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (2): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (3): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (4): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (5): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (6): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (7): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (8): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (9): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (10): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (11): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (12): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (13): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (14): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (15): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (16): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#       (17): Residual_block(
#         (fc_t): Linear(in_features=512, out_features=128, bias=True)
#         (S41): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (conv_layer): Conv(
#           (conv): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (S42): S4Layer(
#           (s4_layer): S4(
#             (kernel): HippoSSKernel(
#               (kernel): SSKernelNPLR()
#             )
#             (activation): GELU(approximate=none)
#             (dropout): Identity()
#             (output_linear): TransposedLinear()
#           )
#           (norm_layer): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Identity()
#         )
#         (cond_conv): Conv(
#           (conv): Conv1d(12, 256, kernel_size=(1,), stride=(1,))
#         )
#         (res_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (skip_conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
#   (final_conv): Sequential(
#     (0): Conv(
#       (conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#     )
#     (1): ReLU()
#     (2): ZeroConv1d(
#       (conv): Conv1d(128, 6, kernel_size=(1,), stride=(1,))
#     )
#   )
# )

# %%
'采样蒸馏模型时 pca等的效果要好 最好输入数据和训练蒸馏时的数据一致 也就是和reflow采样后的数据一致 '
'因为蒸馏时蒸馏的时reflow的采样数据 所以采样蒸馏模型也用一样的数据'
'如果用不同的数据采样蒸馏模型 pca的效果会差一些 肯恩是因为整流法属于一对一的学习 缺少泛化性 '



'用新的数据采样蒸馏模型'
# training_data = np.load(trainset_config['train_data_path'])
# np.random.shuffle(training_data)
# print(training_data.shape)

# training_data = torch.from_numpy(training_data).float().cuda()


# size = (Number, Length, Attribute )

# noise = std_normal(size)

# # mask = get_mask_rm( noise[0], 9)      # 原数据乘以缺失掩码
# # mask = get_mask_mnr( X_0[0], 9) 
# # mask = get_mask_bm( X_0[0], 9) 
# Mask = get_mask_mcar( noise[0], 0.3)

# print( torch.sum(Mask.eq(1)) )

# Mask = Mask.repeat(noise.size()[0], 1, 1).float().cuda()
# print(Mask.shape)


# np.random.shuffle(training_data)


# X_0_hat = training_data.reshape(-1, Length, Attribute)*Mask
# # print(X_0_hat.shape)
# # print(X_0_hat[0])
# # print(mask[0])
# # print(mask[10])

# alpha_hat = Alpha_bar[T_acc - 1].reshape(-1, 1, 1).cuda() 
# X_T_acc = ddpm_x0_to_xt(X_0_hat, alpha_hat, noise)     # 采样起点
# print(X_T_acc.shape)

# # x = x.permute(0, 2, 1)
# # print(x.shape)
# Out:
# '用新的数据采样蒸馏模型'

# %%
'-----------computation overhead-----------'

X_t = X_T_acc.permute(0, 2, 1).cuda()
print(X_t.shape)

distill_step = 1

eps = 0
t = torch.linspace(eps, 1 - eps, distill_step + 1).cuda()
t = t * T_acc 
t= t.int()


start_time = time.time()

with torch.no_grad():  
    for i in range(1, len(t)):
        t_prev = t[i - 1]
        t_prev = t_prev * torch.ones((X_t.shape[0], 1)).cuda()   # [5775, 1])
        
        with torch.no_grad():      
            pred_v = distill_unet( (X_t, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), t_prev.view(X_t.shape[0], 1),) )   
        X_t = X_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 

end_time = time.time()
execution_time = end_time - start_time   # 数据集遍历完一次的时间  sp500差不多9.5s
print(execution_time)  

    
print(X_t.shape)
# Out:
# torch.Size([5775, 6, 30])
# 0.049826622009277344
# torch.Size([5775, 6, 30])

# %%
ori = training_data.cpu()
gen = X_t.permute(0, 2, 1).cpu().numpy()
visualization2(ori, gen)
# Out:
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8000 samples in 0.000s...
# [t-SNE] Computed neighbors for 8000 samples in 0.187s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8000
# [t-SNE] Computed conditional probabilities for sample 2000 / 8000
# [t-SNE] Computed conditional probabilities for sample 3000 / 8000
# [t-SNE] Computed conditional probabilities for sample 4000 / 8000
# [t-SNE] Computed conditional probabilities for sample 5000 / 8000
# [t-SNE] Computed conditional probabilities for sample 6000 / 8000
# [t-SNE] Computed conditional probabilities for sample 7000 / 8000
# [t-SNE] Computed conditional probabilities for sample 8000 / 8000
# [t-SNE] Mean sigma: 0.019688
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.707306
# [t-SNE] KL divergence after 500 iterations: 1.164359
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\PC123\anaconda3\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# result_distill = X_t.permute(0, 2, 1).cpu().detach().numpy().reshape(Number,-1)

# pca = PCA(2)
# pca_res1 = pca.fit_transform(result_distill)

# plt.figure()
# plt.scatter(pca_res1[:,0],pca_res1[:,1])

# %%
'------RMSE-----'
gt = training_data
result = X_t.permute(0, 2, 1)


loss = nn.MSELoss()
output4 = loss(input=result*(1-Mask), target=gt*(1-Mask)  )       # 缺失位置的mse  最重要的指标
print(output4, torch.sqrt(output4))
# Out:
# tensor(0.0002, device='cuda:0') tensor(0.0132, device='cuda:0')

# %%
X_t = X_T_acc.permute(0, 2, 1).cuda()
n_steps = 30
t = torch.linspace(eps, 1 - eps, n_steps + 1).cuda()
t = t * T_acc 
t= t.int()


start_time = time.time()

for i in range(1, len(t)):
    t_prev = t[i - 1]
    t_prev = t_prev * torch.ones((X_t.shape[0], 1)).cuda()  

    with torch.no_grad():         
        pred_v = reflow_unet( (X_t,  X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), t_prev.view(X_t.shape[0], 1),) )   
        
    X_t = X_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 

print(X_t.shape)


end_time = time.time()
execution_time = end_time - start_time   # 数据集遍历完一次的时间  sp500差不多9.5s
print(execution_time)
# Out:
# torch.Size([5775, 6, 30])
# 26.867710828781128

# %%
# result_reflow = X_t.permute(0, 2, 1).cpu().detach().numpy().reshape(Number,-1)

# pca = PCA(2)
# pca_res2 = pca.fit_transform(result_reflow)

# plt.figure()
# plt.scatter(pca_res1[:,0],pca_res1[:,1])
# plt.scatter(pca_res2[:,0],pca_res2[:,1])

# %%
gt = training_data
result = X_t.permute(0, 2, 1)

loss = nn.MSELoss()
output4 = loss(input=result*(1-Mask), target=gt*(1-Mask)  )       # 缺失位置的mse  最重要的指标
print(output4, torch.sqrt(output4))
# Out:
# tensor(0.0002, device='cuda:0') tensor(0.0127, device='cuda:0')

# %%
ori = training_data.cpu()
gen = X_t.permute(0, 2, 1).cpu().numpy()
visualization2(ori, gen)
# Out:
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8000 samples in 0.000s...
# [t-SNE] Computed neighbors for 8000 samples in 0.195s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8000
# [t-SNE] Computed conditional probabilities for sample 2000 / 8000
# [t-SNE] Computed conditional probabilities for sample 3000 / 8000
# [t-SNE] Computed conditional probabilities for sample 4000 / 8000
# [t-SNE] Computed conditional probabilities for sample 5000 / 8000
# [t-SNE] Computed conditional probabilities for sample 6000 / 8000
# [t-SNE] Computed conditional probabilities for sample 7000 / 8000
# [t-SNE] Computed conditional probabilities for sample 8000 / 8000
# [t-SNE] Mean sigma: 0.019013
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.536842
# [t-SNE] KL divergence after 500 iterations: 1.128919
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\PC123\anaconda3\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
'-------rfds蒸馏法-------'
'--------蒸馏---------'
'把上面reflow好的模型 作为基础 看成教师和学生模型'
'应该可以提前用reflow模型的生成数据  直接训练蒸馏 防止一边蒸馏训练一边生成 减少计算时间'

gc.collect()
torch.cuda.empty_cache()

teacher_unet = SSSDS4Imputer(**model_config).cuda()
teacher_unet.load_state_dict(torch.load( "./results/sp500_reflow_mcar0.3.pth"))

student_unet = SSSDS4Imputer(**model_config).cuda()
student_unet.load_state_dict(torch.load( "./results/sp500_reflow_mcar0.3.pth"))

student_unet.cuda()
teacher_unet.cuda()

'学生模型可训练 教师模型固定'
student_unet.train()
teacher_unet.eval()
optimizer = torch.optim.Adam(student_unet.parameters())

# %%
X_t = X_T_acc.permute(0, 2, 1).cuda()
bs = X_t.shape[0]
print(X_t.shape)

# eps = 1e-8         # t从一个很接近0的值开始
# eps = 0.02
n_steps = 30

t = torch.linspace(eps, 1 - eps, n_steps + 1).cuda()
t = t * T_acc 
t= t.int()
print(t)
print(t.shape)
# print(t.view(101,1,1).shape)

print(t[0]-t[1])

t0 = t[0] * torch.ones((X_t.shape[0], 1)).cuda()
print( t0.shape )
print(t[0])
# Out:
# torch.Size([5775, 6, 30])
# tensor([  3,   8,  13,  19,  24,  29,  35,  40,  45,  51,  56,  61,  67,  72,
#          77,  83,  88,  93,  98, 104, 109, 114, 120, 125, 130, 136, 141, 146,
#         152, 157, 162], device='cuda:0', dtype=torch.int32)
# torch.Size([31])
# tensor(-5, device='cuda:0', dtype=torch.int32)
# torch.Size([5775, 1])
# tensor(3, device='cuda:0', dtype=torch.int32)

# %%
iters=0   
n_iters=30
reflow_step = 1   
loss_list = []

while iters < n_iters + 1:         
    for i in range(0, len(dl_X_T_acc)):
        

        x_0 = dl_X_T_acc[i].float().cuda().permute(0, 2, 1) # [128, 6, 30] 缺失数据的加噪值 采样起点
#         x_1 = dl_X_1_gen[i].float().cuda()  # [128, 6, 30] 原数据
        x_0_hat = dl_X_0_hat[i].float().cuda().permute(0, 2, 1)  # 缺失数据  作为条件
        mask = dl_Mask[i].float().cuda().permute(0, 2, 1)

        
        bs = x_0.shape[0]

        '学生模型的一步采样 reflow_step为固定的步长 输入和教师模型相同 比较输出的mse'
        x_t = x_0
        
        t = torch.linspace(eps, 1 - eps, reflow_step + 1).cuda()
        t = t * T_acc 
        t= t.int()
        
        for i in range(1, len(t)):
            t_prev = t[i - 1]
            t_prev = t_prev * torch.ones((x_t.shape[0], 1)).cuda()   # [5775, 1])
            pred_v = student_unet( (x_t, x_0_hat, mask, t_prev.view(bs, 1),) )   
            x_t = x_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 
            
        res_student = x_t
        
        
        '对学生模型的采样结果进行加噪 用教师模型预测速度'
        with torch.no_grad():
            t = torch.randint(min_step, max_step + 1, (x_0.shape[0],) ).cuda()          
            t_view = t.view(bs, 1, 1)
            
            x_t = ( t_view/T_acc ) * res_student + ( 1-t_view/T_acc ) * x_0
            
            pred_v = teacher_unet( (x_t, x_0_hat, mask, t.view(bs, 1),) )   
        
        
        'rfds损失 loss最小在0.007左右'
        grad = torch.nan_to_num(pred_v)
        target = (grad).detach()
        loss = F.mse_loss( x_0 - res_student , target ) 
        
#         loss = F.mse_loss( X_0 - X_1 , target ) 
        
        
        '调换顺序 loss在0.03左右'
#         loss = F.mse_loss( res_student - X_0 , target ) 


        '不用rfds里的detach 使用完整损失 loss最小在0.007左右'
#         loss = F.mse_loss( X_0- res_student, pred_v, reduction="mean") 
            
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
        print(loss)
        loss_list.append(loss.item())
        
    iters += 1
# Out:
# tensor(0.0132, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3.7599, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.9697, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.4439, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.4987, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.6347, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.5280, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3262, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3386, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.5196, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.4661, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3762, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2823, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2261, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1705, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2203, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2160, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2433, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1909, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2668, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3320, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2543, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1845, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1249, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1232, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1319, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1451, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1354, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1139, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1377, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1360, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0769, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0841, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0775, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0902, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0625, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0655, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0703, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0541, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0621, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0703, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0128, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0453, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0414, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0533, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0523, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0459, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0380, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0287, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0321, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0279, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0323, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0372, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0314, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0414, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0363, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0537, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0523, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0495, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0328, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0282, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0260, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0155, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0373, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0227, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0316, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0270, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0253, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0271, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0350, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0237, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0200, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0120, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0162, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0141, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0129, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0126, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0157, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0121, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0174, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0191, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0363, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0412, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0353, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0417, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0448, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0268, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0416, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0368, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0300, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0374, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0142, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0152, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0278, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0147, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0378, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0251, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0237, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0121, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0170, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0157, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0129, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0133, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0141, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0409, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0525, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0599, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0263, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0188, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0170, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0121, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0224, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0112, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0268, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0158, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0254, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0126, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0128, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0120, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0175, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0392, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0639, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0299, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0487, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0239, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0428, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0461, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0413, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0237, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0128, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0133, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0129, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0126, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0173, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0226, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0227, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0286, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0291, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0296, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0452, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0286, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0244, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0215, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0311, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0301, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0139, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0139, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0121, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0275, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0299, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0414, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0424, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0112, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0315, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0141, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0359, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0609, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0580, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0891, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0895, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0452, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0468, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0348, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0200, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0490, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0121, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0266, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0120, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0152, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0211, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0147, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# ...
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0181, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0112, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0133, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0121, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0161, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0260, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0505, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0139, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0270, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0284, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0481, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0323, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0355, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0173, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0147, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0227, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
print(len(loss_list))

plt.figure()
plt.plot(loss_list)
# Out:
# 1426

# %%
X_t = X_T_acc.permute(0, 2, 1).cuda()
print(x_t.shape)

reflow_step = 1

t = torch.linspace(eps, 1 - eps, reflow_step + 1).cuda()
t = t * T_acc 
t= t.int()

with torch.no_grad():  
    for i in range(1, len(t)):
        t_prev = t[i - 1]
        t_prev = t_prev * torch.ones((X_t.shape[0], 1)).cuda()   # [5775, 1])
        
        with torch.no_grad():      
            pred_v = student_unet( (X_t, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), t_prev.view(X_t.shape[0], 1),) )   
            
        X_t = X_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 

print(X_t.shape)
# Out:
# torch.Size([5775, 6, 30])
# torch.Size([5775, 6, 30])

# %%
result_distill = X_t.permute(0, 2, 1).cpu().detach().numpy().reshape(5775,-1)

pca = PCA(2)
pca_res1 = pca.fit_transform(result_distill)

plt.figure()
plt.scatter(pca_res1[:,0],pca_res1[:,1])

# %%
X_t = X_T_acc.permute(0, 2, 1).cuda()

t = torch.linspace(eps, 1 - eps, n_steps + 1).cuda()
t = t * T_acc 
t= t.int()

for i in range(1, len(t)):
    t_prev = t[i - 1]
    t_prev = t_prev * torch.ones((X_t.shape[0], 1)).cuda()  

    with torch.no_grad():         
        pred_v = teacher_unet( (X_t, X_0_hat.permute(0, 2, 1), Mask.permute(0, 2, 1), t_prev.view(X_t.shape[0], 1),) )   
        
    X_t = X_t + ( ( t[i-1] - t[i] )/T_acc ) * pred_v 

print(X_t.shape)
# Out:
# torch.Size([5775, 6, 30])

# %%
result_reflow = X_t.permute(0, 2, 1).cpu().detach().numpy().reshape(5775,-1)

pca = PCA(2)
pca_res2 = pca.fit_transform(result_reflow)

plt.figure()
plt.scatter(pca_res1[:,0],pca_res1[:,1])
plt.scatter(pca_res2[:,0],pca_res2[:,1])
